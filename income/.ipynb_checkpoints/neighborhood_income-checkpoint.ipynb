# %% [markdown]
# # Neighborhood Change
#
# Variables of interest:
# - Income
#
# Geographic unit of analysis:
# - tract

# %% [markdown]
# Task
#
# **ACS dataset**
#
# 1. Filter GEOID to California
#
# 2. Keep variable that represents income
#
# **Tract boundaries**
#
# 1. import data from tl_2018_06_tract folder and get the file that ends with .shp
#
# 2. check and set CRS to 2230
#
# **Merge tract and acs income variables by GEOID**
# 1. dataset produced is tract_income
#
# **Import School Boundaries from quilt**
# 1. nces/sabs/sabs_1516.parquet
#
# 2. clean to CA school boundaries and level = 1 (elementary)
#
# **Spatial Join**
# 1. sjoin of school boundaries and tract_income level data

# %%
import pandas as pd
import geopandas as gpd
import seaborn as sns

# %%
import quilt3
b = quilt3.Bucket("s3://spatial-ucr")
b.fetch("census/acs/acs_2018_tract.parquet", "./acs_2018_tract.parquet")
# Out:
# 100%|██████████| 575M/575M [00:06<00:00, 83.2MB/s]

# %%
acs = gpd.read_parquet('./acs_2018_tract.parquet')

acs.head()
# Out:
#              n_mexican_pop  n_cuban_pop  n_puerto_rican_pop  n_russian_pop  \
# GEOID
# 02020001300           83.0          9.0                 0.0           10.0
# 02020001400          182.0          0.0               123.0            2.0
# 02020001500          206.0          0.0                 0.0           14.0
# 02020001601          254.0          0.0                22.0            0.0
# 02020001602          173.0          0.0                 2.0           14.0
#
#              n_italian_pop  n_german_pop  n_irish_pop  n_scandaniavian_pop  \
# GEOID
# 02020001300           13.0         177.0         73.0                  0.0
# 02020001400           17.0         249.0         45.0                 45.0
# 02020001500           44.0          99.0         90.0                 34.0
# 02020001601            8.0         134.0         76.0                  0.0
# 02020001602            0.0         185.0        113.0                  7.0
#
#              n_foreign_born_pop  n_recent_immigrant_pop  ...  p_veterans  \
# GEOID                                                    ...
# 02020001300               178.0                    49.0  ...    6.715702
# 02020001400               871.0                   296.0  ...    7.132950
# 02020001500               744.0                   383.0  ...    7.089829
# 02020001601               481.0                   100.0  ...    4.066042
# 02020001602               388.0                    95.0  ...   10.044944
#
#              p_poverty_rate  p_poverty_rate_over_65  p_poverty_rate_children  \
# GEOID
# 02020001300        3.952057                0.000000                 0.000000
# 02020001400       18.109294                0.039888                 2.951735
# 02020001500        5.586802                0.712411                 0.000000
# 02020001601        4.160363                0.579929                 0.176500
# 02020001602        5.344089                0.504159                 0.403327
#
#              p_poverty_rate_white  p_poverty_rate_black  \
# GEOID
# 02020001300              3.952057              0.000000
# 02020001400              3.749501             12.584763
# 02020001500              3.355831              0.000000
# 02020001601              1.487645              0.277358
# 02020001602              1.890597              0.680615
#
#              p_poverty_rate_hispanic  p_poverty_rate_native  \
# GEOID
# 02020001300                 1.068999               0.000000
# 02020001400                 0.518548               1.196649
# 02020001500                 0.806149               0.712411
# 02020001601                 0.403429               0.327786
# 02020001602                 0.000000               0.932695
#
#              p_poverty_rate_asian  \
# GEOID
# 02020001300              0.000000
# 02020001400              0.000000
# 02020001500              0.000000
# 02020001601              0.554715
# 02020001602              0.000000
#
#                                                       geometry
# GEOID
# 02020001300  MULTIPOLYGON (((-149.98205 61.22613, -149.9676...
# 02020001400  MULTIPOLYGON (((-149.91326 61.19631, -149.9132...
# 02020001500  MULTIPOLYGON (((-149.86817 61.19528, -149.8681...
# 02020001601  MULTIPOLYGON (((-149.83828 61.20771, -149.8380...
# 02020001602  MULTIPOLYGON (((-149.83826 61.19537, -149.8377...
#
# [5 rows x 155 columns]

# %%
acs.columns

# GEOID is not a column but the index
# Out:
# Index(['n_mexican_pop', 'n_cuban_pop', 'n_puerto_rican_pop', 'n_russian_pop',
#        'n_italian_pop', 'n_german_pop', 'n_irish_pop', 'n_scandaniavian_pop',
#        'n_foreign_born_pop', 'n_recent_immigrant_pop',
#        ...
#        'p_veterans', 'p_poverty_rate', 'p_poverty_rate_over_65',
#        'p_poverty_rate_children', 'p_poverty_rate_white',
#        'p_poverty_rate_black', 'p_poverty_rate_hispanic',
#        'p_poverty_rate_native', 'p_poverty_rate_asian', 'geometry'],
#       dtype='object', length=155)

# %%
acs = acs.reset_index()

# before GEOID is in the index, by resetting the index it turns GEOID into a column

# %%
acs.columns

# GEOID is now apart of the columns
# Out:
# Index(['GEOID', 'n_mexican_pop', 'n_cuban_pop', 'n_puerto_rican_pop',
#        'n_russian_pop', 'n_italian_pop', 'n_german_pop', 'n_irish_pop',
#        'n_scandaniavian_pop', 'n_foreign_born_pop',
#        ...
#        'p_veterans', 'p_poverty_rate', 'p_poverty_rate_over_65',
#        'p_poverty_rate_children', 'p_poverty_rate_white',
#        'p_poverty_rate_black', 'p_poverty_rate_hispanic',
#        'p_poverty_rate_native', 'p_poverty_rate_asian', 'geometry'],
#       dtype='object', length=156)

# %%
ca_acs = acs[acs.GEOID.str.startswith('06')]

#filter acs dataset by the column GEOID by the row values that starts with 06

# %%
ca_acs.head()
# Out:
#             GEOID  n_mexican_pop  n_cuban_pop  n_puerto_rican_pop  \
# 3560  06037554001         1718.0          0.0                34.0
# 3561  06037554002         2872.0         63.0                 0.0
# 3562  06037554101         2486.0          0.0                17.0
# 3563  06037554103          750.0         10.0                 6.0
# 3564  06037554104         1303.0          0.0                 0.0
#
#       n_russian_pop  n_italian_pop  n_german_pop  n_irish_pop  \
# 3560            0.0           32.0         267.0         39.0
# 3561            0.0           27.0           0.0          0.0
# 3562            0.0            8.0          10.0          0.0
# 3563            4.0            0.0          11.0         13.0
# 3564            0.0            0.0          11.0          0.0
#
#       n_scandaniavian_pop  n_foreign_born_pop  ...  p_veterans  \
# 3560                  0.0               987.0  ...    5.762338
# 3561                  0.0              2175.0  ...    1.266473
# 3562                  0.0              1448.0  ...    2.134063
# 3563                  0.0               541.0  ...    1.444517
# 3564                  0.0               918.0  ...    1.157685
#
#       p_poverty_rate  p_poverty_rate_over_65  p_poverty_rate_children  \
# 3560       12.131238                0.634133                 2.371106
# 3561       13.695578                0.548509                 2.005485
# 3562       22.051984                0.601915                 3.556772
# 3563        8.486842                0.657895                 0.921053
# 3564       23.281062                2.010454                 3.136309
#
#       p_poverty_rate_white  p_poverty_rate_black  p_poverty_rate_hispanic  \
# 3560              5.596912              0.275710                10.862972
# 3561              6.102160              2.125471                 7.576277
# 3562              3.091655              1.723666                18.002736
# 3563              1.710526              0.000000                 6.118421
# 3564              5.106554              1.367109                17.571371
#
#       p_poverty_rate_native  p_poverty_rate_asian  \
# 3560               0.000000                   0.0
# 3561               0.000000                   0.0
# 3562               0.218878                   0.0
# 3563               0.000000                   0.0
# 3564               0.000000                   0.0
#
#                                                geometry
# 3560  MULTIPOLYGON (((-118.14073 33.89670, -118.1397...
# 3561  MULTIPOLYGON (((-118.14279 33.89649, -118.1426...
# 3562  MULTIPOLYGON (((-118.12531 33.90038, -118.1251...
# 3563  MULTIPOLYGON (((-118.12532 33.90200, -118.1250...
# 3564  MULTIPOLYGON (((-118.12203 33.89663, -118.1216...
#
# [5 rows x 156 columns]

# %%
ca_acs.columns
# Out:
# Index(['GEOID', 'n_mexican_pop', 'n_cuban_pop', 'n_puerto_rican_pop',
#        'n_russian_pop', 'n_italian_pop', 'n_german_pop', 'n_irish_pop',
#        'n_scandaniavian_pop', 'n_foreign_born_pop',
#        ...
#        'p_veterans', 'p_poverty_rate', 'p_poverty_rate_over_65',
#        'p_poverty_rate_children', 'p_poverty_rate_white',
#        'p_poverty_rate_black', 'p_poverty_rate_hispanic',
#        'p_poverty_rate_native', 'p_poverty_rate_asian', 'geometry'],
#       dtype='object', length=156)

# %%
ca_acs.median_household_income.unique()
# Out:
# array([55703., 56452., 42969., ..., 69159., 83194., 45434.])

# %%
income = ca_acs[['GEOID','median_household_income','median_home_value','per_capita_income']]

# %%
income.head()
# Out:
#             GEOID  median_household_income  median_home_value  \
# 3560  06037554001                  55703.0           450200.0
# 3561  06037554002                  56452.0           461200.0
# 3562  06037554101                  42969.0           453200.0
# 3563  06037554103                  81480.0           460200.0
# 3564  06037554104                  63625.0           464800.0
#
#       per_capita_income
# 3560            23331.0
# 3561            22520.0
# 3562            19127.0
# 3563            34880.0
# 3564            20344.0

# %% [markdown]
# # Import tract level data for geometries

# %%
tract = gpd.read_file('./tl_2018_06_tract/tl_2018_06_tract.shp')

#right click the shapefile > copy path > PBPL280S21Project1/tl_2018_06_tract/tl_2018_06_tract.shp

# %%
tract.head()
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID     NAME              NAMELSAD  MTFCC  \
# 0      06      037  137504  06037137504  1375.04  Census Tract 1375.04  G5020
# 1      06      037  138000  06037138000     1380     Census Tract 1380  G5020
# 2      06      037  139200  06037139200     1392     Census Tract 1392  G5020
# 3      06      067  002300  06067002300       23       Census Tract 23  G5020
# 4      06      067  002400  06067002400       24       Census Tract 24  G5020
#
#   FUNCSTAT    ALAND  AWATER     INTPTLAT      INTPTLON  \
# 0        S  3837562       0  +34.1480383  -118.5720594
# 1        S  4472196       0  +34.1488008  -118.5910495
# 2        S  1152031       0  +34.1756961  -118.5246447
# 3        S  1213095       0  +38.5571708  -121.4938311
# 4        S  3224718       0  +38.5448312  -121.4973382
#
#                                             geometry
# 0  POLYGON ((-118.58119 34.14318, -118.58099 34.1...
# 1  POLYGON ((-118.60573 34.14585, -118.60561 34.1...
# 2  POLYGON ((-118.53082 34.18024, -118.52952 34.1...
# 3  POLYGON ((-121.50218 38.55643, -121.50184 38.5...
# 4  POLYGON ((-121.50970 38.54070, -121.50960 38.5...

# %%
tract.shape
# Out:
# (8057, 13)

# %%
tract.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - NAD83
# - bounds: (167.65, 14.92, -47.74, 86.46)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
tract = tract.to_crs(2230)

# %% [markdown]
# # merge the neighborhood variables income to get a dataset with the income variables, geoids, and geometries

# %%
type(tract)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
type(income)

# need to check to see if both dataframes are geodataframes if not we convert them to a geodataframe
# Out:
# pandas.core.frame.DataFrame

# %%
income = gpd.GeoDataFrame(income)

#convert pandas dataframe into a geodataframe with this code

# %%
tract_income = income.merge(tract, how='left', on='GEOID')

# %%
tract_income
# Out:
#             GEOID  median_household_income  median_home_value  \
# 0     06037554001                  55703.0           450200.0
# 1     06037554002                  56452.0           461200.0
# 2     06037554101                  42969.0           453200.0
# 3     06037554103                  81480.0           460200.0
# 4     06037554104                  63625.0           464800.0
# ...           ...                      ...                ...
# 8052  06115040800                  69159.0           254500.0
# 8053  06115040901                  57969.0           205000.0
# 8054  06115040902                  45250.0                NaN
# 8055  06115041000                  83194.0           327200.0
# 8056  06115041100                  45434.0           205500.0
#
#       per_capita_income STATEFP COUNTYFP TRACTCE     NAME  \
# 0               23331.0      06      037  554001  5540.01
# 1               22520.0      06      037  554002  5540.02
# 2               19127.0      06      037  554101  5541.01
# 3               34880.0      06      037  554103  5541.03
# 4               20344.0      06      037  554104  5541.04
# ...                 ...     ...      ...     ...      ...
# 8052            32816.0      06      115  040800      408
# 8053            25904.0      06      115  040901   409.01
# 8054            19183.0      06      115  040902   409.02
# 8055            39049.0      06      115  041000      410
# 8056            28558.0      06      115  041100      411
#
#                   NAMELSAD  MTFCC FUNCSTAT      ALAND    AWATER     INTPTLAT  \
# 0     Census Tract 5540.01  G5020        S    1082739         0  +33.8990638
# 1     Census Tract 5540.02  G5020        S    1269668         0  +33.8922721
# 2     Census Tract 5541.01  G5020        S     473914         0  +33.8928105
# 3     Census Tract 5541.03  G5020        S     368572         0  +33.8996980
# 4     Census Tract 5541.04  G5020        S     364478         0  +33.8931415
# ...                    ...    ...      ...        ...       ...          ...
# 8052      Census Tract 408  G5020        S  109401416    128316  +39.0410532
# 8053   Census Tract 409.01  G5020        S  263652570   4473094  +39.1397434
# 8054   Census Tract 409.02  G5020        S   93617079    240059  +39.1191804
# 8055      Census Tract 410  G5020        S  468397390   6927408  +39.2661888
# 8056      Census Tract 411  G5020        S  559316287  17080393  +39.4522438
#
#           INTPTLON                                           geometry
# 0     -118.1322329  POLYGON ((5987925.784 2275112.258, 5988249.105...
# 1     -118.1336322  POLYGON ((5987299.089 2275049.015, 5987348.882...
# 2     -118.1236012  POLYGON ((5992628.264 2276367.468, 5992690.382...
# 3     -118.1201748  POLYGON ((5992635.820 2276956.239, 5992710.707...
# 4     -118.1195565  POLYGON ((5993599.563 2274986.574, 5993703.488...
# ...            ...                                                ...
# 8052  -121.4339803  POLYGON ((5058959.284 4180341.579, 5059024.590...
# 8053  -121.5823399  POLYGON ((5041586.069 4219922.530, 5041642.867...
# 8054  -121.3995270  POLYGON ((5071766.110 4217339.958, 5071993.551...
# 8055  -121.4453728  POLYGON ((5028575.474 4260876.310, 5028615.848...
# 8056  -121.1826541  POLYGON ((5105889.350 4303734.816, 5105901.755...
#
# [8057 rows x 16 columns]

# %%
tract_income.columns
# Out:
# Index(['GEOID', 'median_household_income', 'median_home_value',
#        'per_capita_income', 'STATEFP', 'COUNTYFP', 'TRACTCE', 'NAME',
#        'NAMELSAD', 'MTFCC', 'FUNCSTAT', 'ALAND', 'AWATER', 'INTPTLAT',
#        'INTPTLON', 'geometry'],
#       dtype='object')

# %%
tract_income = tract_income[['GEOID','median_household_income','median_home_value','per_capita_income','geometry']]

# %%
tract_income
# Out:
#             GEOID  median_household_income  median_home_value  \
# 0     06037554001                  55703.0           450200.0
# 1     06037554002                  56452.0           461200.0
# 2     06037554101                  42969.0           453200.0
# 3     06037554103                  81480.0           460200.0
# 4     06037554104                  63625.0           464800.0
# ...           ...                      ...                ...
# 8052  06115040800                  69159.0           254500.0
# 8053  06115040901                  57969.0           205000.0
# 8054  06115040902                  45250.0                NaN
# 8055  06115041000                  83194.0           327200.0
# 8056  06115041100                  45434.0           205500.0
#
#       per_capita_income                                           geometry
# 0               23331.0  POLYGON ((5987925.784 2275112.258, 5988249.105...
# 1               22520.0  POLYGON ((5987299.089 2275049.015, 5987348.882...
# 2               19127.0  POLYGON ((5992628.264 2276367.468, 5992690.382...
# 3               34880.0  POLYGON ((5992635.820 2276956.239, 5992710.707...
# 4               20344.0  POLYGON ((5993599.563 2274986.574, 5993703.488...
# ...                 ...                                                ...
# 8052            32816.0  POLYGON ((5058959.284 4180341.579, 5059024.590...
# 8053            25904.0  POLYGON ((5041586.069 4219922.530, 5041642.867...
# 8054            19183.0  POLYGON ((5071766.110 4217339.958, 5071993.551...
# 8055            39049.0  POLYGON ((5028575.474 4260876.310, 5028615.848...
# 8056            28558.0  POLYGON ((5105889.350 4303734.816, 5105901.755...
#
# [8057 rows x 5 columns]

# %%
tract_income.head()
# Out:
#          GEOID  median_household_income  median_home_value  per_capita_income  \
# 0  06037554001                  55703.0           450200.0            23331.0
# 1  06037554002                  56452.0           461200.0            22520.0
# 2  06037554101                  42969.0           453200.0            19127.0
# 3  06037554103                  81480.0           460200.0            34880.0
# 4  06037554104                  63625.0           464800.0            20344.0
#
#                                             geometry
# 0  POLYGON ((5987925.784 2275112.258, 5988249.105...
# 1  POLYGON ((5987299.089 2275049.015, 5987348.882...
# 2  POLYGON ((5992628.264 2276367.468, 5992690.382...
# 3  POLYGON ((5992635.820 2276956.239, 5992710.707...
# 4  POLYGON ((5993599.563 2274986.574, 5993703.488...

# %%
#tract_income.to_parquet('ca_tract_incomes.parquet')
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: this is an initial implementation of Parquet/Feather file support and associated metadata.  This is tracking version 0.1.0 of the metadata specification at https://github.com/geopandas/geo-arrow-spec
#
# This metadata specification does not yet make stability promises.  We do not yet recommend using this in a production setting unless you are able to rewrite your Parquet/Feather files.
#
# To further ignore this warning, you can do:
# import warnings; warnings.filterwarnings('ignore', message='.*initial implementation of Parquet.*')
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Riverside County

# %%
riverside_income = tract_income[tract_income.GEOID.str.startswith('06065')]

# %%
riverside_income
# Out:
#             GEOID  median_household_income  median_home_value  \
# 6045  06065043252                 123032.0           478400.0
# 6046  06065043254                  81939.0           354500.0
# 6047  06065043256                  90175.0           370800.0
# 6048  06065043257                 118041.0           571600.0
# 6049  06065043262                 105190.0           420400.0
# ...           ...                      ...                ...
# 7984  06065043244                  87873.0           438100.0
# 7985  06065043246                 106294.0           500800.0
# 7986  06065043247                 110227.0           431600.0
# 7987  06065043248                 115625.0           458100.0
# 7988  06065043250                  85583.0           410800.0
#
#       per_capita_income                                           geometry
# 6045            38218.0  POLYGON ((6300069.665 2111924.118, 6300099.846...
# 6046            30557.0  POLYGON ((6256505.532 2109427.087, 6256517.353...
# 6047            28609.0  POLYGON ((6302033.793 2119457.866, 6302083.922...
# 6048            36308.0  POLYGON ((6303612.173 2107665.775, 6304427.770...
# 6049            40419.0  POLYGON ((6295070.451 2129495.784, 6295073.799...
# ...                 ...                                                ...
# 7984            31403.0  POLYGON ((6289367.120 2142136.136, 6289399.168...
# 7985            40089.0  POLYGON ((6304318.656 2133618.798, 6304353.586...
# 7986            29704.0  POLYGON ((6290462.295 2146030.218, 6290498.075...
# 7987            35508.0  POLYGON ((6303712.339 2115049.220, 6303717.146...
# 7988            34472.0  POLYGON ((6293603.200 2117808.116, 6293802.198...
#
# [453 rows x 5 columns]

# %%
riverside_income = riverside_income[['GEOID','median_household_income','geometry']]

# %%
riverside_income
# Out:
#             GEOID  median_household_income  \
# 6045  06065043252                 123032.0
# 6046  06065043254                  81939.0
# 6047  06065043256                  90175.0
# 6048  06065043257                 118041.0
# 6049  06065043262                 105190.0
# ...           ...                      ...
# 7984  06065043244                  87873.0
# 7985  06065043246                 106294.0
# 7986  06065043247                 110227.0
# 7987  06065043248                 115625.0
# 7988  06065043250                  85583.0
#
#                                                geometry
# 6045  POLYGON ((6300069.665 2111924.118, 6300099.846...
# 6046  POLYGON ((6256505.532 2109427.087, 6256517.353...
# 6047  POLYGON ((6302033.793 2119457.866, 6302083.922...
# 6048  POLYGON ((6303612.173 2107665.775, 6304427.770...
# 6049  POLYGON ((6295070.451 2129495.784, 6295073.799...
# ...                                                 ...
# 7984  POLYGON ((6289367.120 2142136.136, 6289399.168...
# 7985  POLYGON ((6304318.656 2133618.798, 6304353.586...
# 7986  POLYGON ((6290462.295 2146030.218, 6290498.075...
# 7987  POLYGON ((6303712.339 2115049.220, 6303717.146...
# 7988  POLYGON ((6293603.200 2117808.116, 6293802.198...
#
# [453 rows x 3 columns]

# %%
#riverside_income.to_parquet('riverside_income.parquet')

# %% [markdown]
# # San Diego County

# %%
sd_income = tract_income[tract_income.GEOID.str.startswith('06073')]

# %%
sd_income = sd_income[['GEOID','median_household_income','geometry']]

# %%
sd_income.head()
# Out:
#             GEOID  median_household_income  \
# 3995  06073016809                  93500.0
# 3996  06073016810                  86442.0
# 3997  06073016811                  71250.0
# 3998  06073016901                  90859.0
# 3999  06073016902                  93750.0
#
#                                                geometry
# 3995  POLYGON ((6356264.930 1875989.112, 6356373.941...
# 3996  POLYGON ((6356070.107 1891633.170, 6356084.247...
# 3997  POLYGON ((6359599.903 1884610.154, 6359828.308...
# 3998  POLYGON ((6332393.436 1902845.350, 6332761.116...
# 3999  POLYGON ((6352081.727 1903549.063, 6352082.072...

# %%
#sd_income.to_parquet('sd_income.parquet')
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: this is an initial implementation of Parquet/Feather file support and associated metadata.  This is tracking version 0.1.0 of the metadata specification at https://github.com/geopandas/geo-arrow-spec
#
# This metadata specification does not yet make stability promises.  We do not yet recommend using this in a production setting unless you are able to rewrite your Parquet/Feather files.
#
# To further ignore this warning, you can do:
# import warnings; warnings.filterwarnings('ignore', message='.*initial implementation of Parquet.*')
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## San Bernardino

# %%
sb_income = tract_income[tract_income.GEOID.str.startswith('06071')]

# %%
sb_income = sb_income[['GEOID','median_household_income','geometry']]

# %%
sb_income.head()
# Out:
#             GEOID  median_household_income  \
# 5977  06071000103                  90305.0
# 5978  06071000104                 107019.0
# 5979  06071000105                 117852.0
# 5980  06071000107                 103500.0
# 5981  06071005400                  37014.0
#
#                                                geometry
# 5977  POLYGON ((6101749.720 2317986.973, 6101772.943...
# 5978  POLYGON ((6101010.988 2312550.620, 6101190.966...
# 5979  POLYGON ((6104501.109 2309301.782, 6104540.080...
# 5980  POLYGON ((6112249.300 2306996.683, 6112285.971...
# 5981  POLYGON ((6242930.917 2356123.532, 6242932.489...

# %%
tract_income.plot(column='median_household_income', scheme='FisherJenks', k=5, legend=True, figsize=(15,15))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # End

# %%
riverside_homevalue = tract_income[tract_income.GEOID.str.startswith('06065')]

# %%
riverside_homevalue
# Out:
#             GEOID  median_household_income  median_home_value  \
# 6045  06065043252                 123032.0           478400.0
# 6046  06065043254                  81939.0           354500.0
# 6047  06065043256                  90175.0           370800.0
# 6048  06065043257                 118041.0           571600.0
# 6049  06065043262                 105190.0           420400.0
# ...           ...                      ...                ...
# 7984  06065043244                  87873.0           438100.0
# 7985  06065043246                 106294.0           500800.0
# 7986  06065043247                 110227.0           431600.0
# 7987  06065043248                 115625.0           458100.0
# 7988  06065043250                  85583.0           410800.0
#
#       per_capita_income                                           geometry
# 6045            38218.0  POLYGON ((6300069.665 2111924.118, 6300099.846...
# 6046            30557.0  POLYGON ((6256505.532 2109427.087, 6256517.353...
# 6047            28609.0  POLYGON ((6302033.793 2119457.866, 6302083.922...
# 6048            36308.0  POLYGON ((6303612.173 2107665.775, 6304427.770...
# 6049            40419.0  POLYGON ((6295070.451 2129495.784, 6295073.799...
# ...                 ...                                                ...
# 7984            31403.0  POLYGON ((6289367.120 2142136.136, 6289399.168...
# 7985            40089.0  POLYGON ((6304318.656 2133618.798, 6304353.586...
# 7986            29704.0  POLYGON ((6290462.295 2146030.218, 6290498.075...
# 7987            35508.0  POLYGON ((6303712.339 2115049.220, 6303717.146...
# 7988            34472.0  POLYGON ((6293603.200 2117808.116, 6293802.198...
#
# [453 rows x 5 columns]

# %%
riverside_homevalue = riverside_homevalue[['GEOID','median_home_value','geometry']]

# %%
riverside_homevalue
# Out:
#             GEOID  median_home_value  \
# 6045  06065043252           478400.0
# 6046  06065043254           354500.0
# 6047  06065043256           370800.0
# 6048  06065043257           571600.0
# 6049  06065043262           420400.0
# ...           ...                ...
# 7984  06065043244           438100.0
# 7985  06065043246           500800.0
# 7986  06065043247           431600.0
# 7987  06065043248           458100.0
# 7988  06065043250           410800.0
#
#                                                geometry
# 6045  POLYGON ((6300069.665 2111924.118, 6300099.846...
# 6046  POLYGON ((6256505.532 2109427.087, 6256517.353...
# 6047  POLYGON ((6302033.793 2119457.866, 6302083.922...
# 6048  POLYGON ((6303612.173 2107665.775, 6304427.770...
# 6049  POLYGON ((6295070.451 2129495.784, 6295073.799...
# ...                                                 ...
# 7984  POLYGON ((6289367.120 2142136.136, 6289399.168...
# 7985  POLYGON ((6304318.656 2133618.798, 6304353.586...
# 7986  POLYGON ((6290462.295 2146030.218, 6290498.075...
# 7987  POLYGON ((6303712.339 2115049.220, 6303717.146...
# 7988  POLYGON ((6293603.200 2117808.116, 6293802.198...
#
# [453 rows x 3 columns]

# %%
riverside_homevalue.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 453 entries, 6045 to 7988
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GEOID              453 non-null    object
#  1   median_home_value  450 non-null    float64
#  2   geometry           453 non-null    geometry
# dtypes: float64(1), geometry(1), object(1)
# memory usage: 14.2+ KB

# %%
riverside_homevalue.plot(figsize=(15,15))
# Out:
# <AxesSubplot:>

# %%
#riverside_homevalue.to_parquet('riverside_homevalue.parquet')

# %%
tract_income.plot(column='median_home_value', scheme='FisherJenks', k=5, legend=True, figsize=(15,15))
# Out:
# <AxesSubplot:>

# %%
# CRS

# %%
tract_income_copy = tract_income.copy()

# %%
tract_income_copy.crs = "EPSG:2230"

# https://stackoverflow.com/questions/64421284/geopandas-valueerror-cannot-transform-naive-geometries-please-set-a-crs-on-t

# %%
#tract_income_copy = tract_income_copy.crs(epsg=2230)

# %%
tract_income_copy.crs
# Out:
# <Projected CRS: EPSG:2230>
# Name: NAD83 / California zone 6 (ftUS)
# Axis Info [cartesian]:
# - X[east]: Easting (US survey foot)
# - Y[north]: Northing (US survey foot)
# Area of Use:
# - name: USA - California - SPCS - 6
# - bounds: (-118.15, 32.53, -114.42, 34.08)
# Coordinate Operation:
# - name: SPCS83 California zone 6 (US Survey feet)
# - method: Lambert Conic Conformal (2SP)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %% [markdown]
# # Import school district boundaries

# %%
import quilt3
b = quilt3.Bucket("s3://spatial-ucr")
b.fetch("nces/sabs/sabs_1516.parquet", "./sabs_1516.parquet")
# Out:
# 100%|██████████| 241M/241M [00:05<00:00, 41.4MB/s]

# %%
sabs = gpd.read_parquet('./sabs_1516.parquet')

sabs.head()
# Out:
#   SrcName       ncessch                       schnam    leaid gslo gshi  \
# 0    None  010000500870        Ala Avenue Middle Sch  0100005   07   08
# 1    None  010000500871         Albertville High Sch  0100005   09   12
# 2    None  010000500879               Evans Elem Sch  0100005   05   06
# 3    None  010000500889         Albertville Elem Sch  0100005   03   04
# 4    None  010000501616  Big Spring Lake Kinderg Sch  0100005   KG   KG
#
#   defacto stAbbrev openEnroll     Shape_Leng    Shape_Area level MultiBdy  \
# 0       1       AL          0  146828.793028  1.012552e+08     2        0
# 1       1       AL          0  146828.793028  1.012552e+08     3        0
# 2       1       AL          0  146828.793028  1.012552e+08     2        0
# 3       1       AL          0  146828.793028  1.012552e+08     1        0
# 4       1       AL          0  146828.793028  1.012552e+08     1        0
#
#                                             geometry
# 0  MULTIPOLYGON (((-9601421.827 4062780.032, -960...
# 1  MULTIPOLYGON (((-9601421.827 4062780.032, -960...
# 2  MULTIPOLYGON (((-9601421.827 4062780.032, -960...
# 3  MULTIPOLYGON (((-9601421.827 4062780.032, -960...
# 4  MULTIPOLYGON (((-9601421.827 4062780.032, -960...

# %%
sabs = sabs[sabs['stAbbrev'] == 'CA']

# %%
sabs
# Out:
#                      SrcName       ncessch                 schnam    leaid  \
# 3792            Vasquez High  060000103278           Vasquez High  0600001
# 3793   Meadowlark Elementary  060000107534  Meadowlark Elementary  0600001
# 3794             High Desert  060000109444            High Desert  0600001
# 3795            Not provided  060000199991             Unassigned  0600001
# 3796            Not provided  060000199992             Unassigned  0600001
# ...                      ...           ...                    ...      ...
# 11374           May Ranch ES  069113512262   May Ranch Elementary  0691135
# 11375                   None  069113513435  El Potrero Pre-School  0691135
# 11376                   None  069113710339             Tioga High  0691137
# 11377                   None  069113710340         Don Pedro High  0691137
# 11378                   None  069113710341      Tenaya Elementary  0691137
#
#       gslo gshi defacto stAbbrev openEnroll     Shape_Leng    Shape_Area  \
# 3792    09   12       0       CA          0  133901.224937  8.089787e+08
# 3793    KG   05       0       CA          0   98640.270744  4.097022e+08
# 3794    06   08       0       CA          0  133901.224937  8.089787e+08
# 3795    KG   05       0       CA          0   12587.404553  9.853027e+06
# 3796    06   08       0       CA          0   12587.404553  9.853027e+06
# ...    ...  ...     ...      ...        ...            ...           ...
# 11374   KG   05       0       CA          0   25567.027066  2.040861e+07
# 11375    N    N       0       CA          1   78933.485082  2.190421e+08
# 11376   09   12       0       CA          2  512279.958807  2.745537e+09
# 11377   09   12       0       CA          2  512279.958807  2.745537e+09
# 11378   KG   08       0       CA          2  512279.958807  2.745537e+09
#
#       level MultiBdy                                           geometry
# 3792      3        0  POLYGON ((-13162468.047 4103989.263, -13161303...
# 3793      1        0  POLYGON ((-13156328.553 4104009.539, -13156326...
# 3794      2        0  POLYGON ((-13162468.047 4103989.263, -13161303...
# 3795      1        0  POLYGON ((-13171958.590 4087695.227, -13172297...
# 3796      2        0  POLYGON ((-13171958.590 4087695.227, -13172297...
# ...     ...      ...                                                ...
# 11374     1        0  POLYGON ((-13052782.727 4011378.522, -13052465...
# 11375     N        0  POLYGON ((-13049569.352 4015038.339, -13049569...
# 11376     3        0  POLYGON ((-13409757.024 4542122.022, -13409750...
# 11377     3        0  POLYGON ((-13409757.024 4542122.022, -13409750...
# 11378     1        0  POLYGON ((-13409757.024 4542122.022, -13409750...
#
# [7587 rows x 14 columns]

# %%
sabs = sabs[sabs['level']=='3']

# %%
sabs
# Out:
#                        SrcName       ncessch              schnam    leaid  \
# 3792              Vasquez High  060000103278        Vasquez High  0600001
# 3797              Not provided  060000199993          Unassigned  0600001
# 3804                      None  060000908779  Cuyama Valley High  0600009
# 3806                      None  060001109065        Herlong High  0600011
# 3813              Rocklin High  060001302405        Rocklin High  0600013
# ...                        ...           ...                 ...      ...
# 11351  Tranquility High School  069113410214   Tranquillity High  0691134
# 11360          Rancho Verde HS  069113510283   Rancho Verde High  0691135
# 11367           Citrus Hill HS  069113511047    Citrus Hill High  0691135
# 11376                     None  069113710339          Tioga High  0691137
# 11377                     None  069113710340      Don Pedro High  0691137
#
#       gslo gshi defacto stAbbrev openEnroll     Shape_Leng    Shape_Area  \
# 3792    09   12       0       CA          0  133901.224937  8.089787e+08
# 3797    09   12       0       CA          0   12587.404553  9.853027e+06
# 3804    09   12       1       CA          0  376387.196533  2.803499e+09
# 3806    09   12       1       CA          0  209495.629862  1.173091e+09
# 3813    09   12       0       CA          0   30541.411329  3.749821e+07
# ...    ...  ...     ...      ...        ...            ...           ...
# 11351   09   12       0       CA          0  202114.613809  1.459830e+09
# 11360   09   12       0       CA          0   47821.994152  7.709802e+07
# 11367   09   12       0       CA          0   63686.623347  1.419441e+08
# 11376   09   12       0       CA          2  512279.958807  2.745537e+09
# 11377   09   12       0       CA          2  512279.958807  2.745537e+09
#
#       level MultiBdy                                           geometry
# 3792      3        0  POLYGON ((-13162468.047 4103989.263, -13161303...
# 3797      3        0  POLYGON ((-13171958.590 4087695.227, -13172297...
# 3804      3        0  POLYGON ((-13368691.450 4178109.983, -13368692...
# 3806      3        0  POLYGON ((-13391935.918 4887057.454, -13391294...
# 3813      3        0  POLYGON ((-13494203.016 4698673.000, -13494203...
# ...     ...      ...                                                ...
# 11351     3        0  POLYGON ((-13381130.310 4404206.060, -13381130...
# 11360     3        0  POLYGON ((-13046321.494 4014840.255, -13046224...
# 11367     3        0  POLYGON ((-13049569.352 4015038.339, -13049569...
# 11376     3        0  POLYGON ((-13409757.024 4542122.022, -13409750...
# 11377     3        0  POLYGON ((-13409757.024 4542122.022, -13409750...
#
# [1037 rows x 14 columns]

# %%
sabs.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 1037 entries, 3792 to 11377
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SrcName     774 non-null    object
#  1   ncessch     1037 non-null   object
#  2   schnam      1037 non-null   object
#  3   leaid       1037 non-null   object
#  4   gslo        1037 non-null   object
#  5   gshi        1037 non-null   object
#  6   defacto     1037 non-null   object
#  7   stAbbrev    1037 non-null   object
#  8   openEnroll  1037 non-null   object
#  9   Shape_Leng  1037 non-null   float64
#  10  Shape_Area  1037 non-null   float64
#  11  level       1037 non-null   object
#  12  MultiBdy    1037 non-null   object
#  13  geometry    1037 non-null   geometry
# dtypes: float64(2), geometry(1), object(11)
# memory usage: 121.5+ KB

# %%
sabs.plot(figsize=(15,15))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # CRS

# %%
sabs.crs
# Out:
# <Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World - 85°S to 85°N
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: unnamed
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
sabs = sabs.to_crs(2230)

# %%
ca_sabs = sabs.copy()

# %%
#ca_sabs.to_parquet('ca_sabs.parquet')

# %% [markdown]
# # Spatial Join

# %%
sabs_tract_income = gpd.sjoin(sabs, tract_income_copy, how='inner', op='intersects')

# %%
sabs_tract_income.head()
# Out:
#            SrcName       ncessch                         schnam    leaid gslo  \
# 3792  Vasquez High  060000103278                   Vasquez High  0600001   09
# 3851     Upland HS  060001609086                    Upland High  0600016   09
# 4495    Littlerock  060282009516                Littlerock High  0602820   09
# 4497        Knight  060282011346  William J. (Pete) Knight High  0602820   09
# 4576  Not provided  060360099993                     Unassigned  0603600   09
#
#      gshi defacto stAbbrev openEnroll     Shape_Leng    Shape_Area level  \
# 3792   12       0       CA          0  133901.224937  8.089787e+08     3
# 3851   12       0       CA          0   51710.014112  1.001008e+08     3
# 4495   12       0       CA          0  161972.944342  1.350265e+09     3
# 4497   12       0       CA          0   98925.363711  2.956851e+08     3
# 4576   12       0       CA          0  125865.100380  5.304450e+08     3
#
#      MultiBdy                                           geometry  index_right  \
# 3792        0  POLYGON ((5962260.588 2516356.115, 5965409.303...           51
# 3851        0  POLYGON ((6144057.828 2373247.809, 6144039.605...           51
# 4495        0  POLYGON ((6046490.715 2450291.767, 6046490.753...           51
# 4497        0  POLYGON ((6032604.779 2541662.837, 6033520.381...           51
# 4576        0  POLYGON ((6065465.329 2366047.477, 6065447.216...           51
#
#             GEOID  median_household_income  median_home_value  \
# 3792  06037930301                  75313.0           310300.0
# 3851  06037930301                  75313.0           310300.0
# 4495  06037930301                  75313.0           310300.0
# 4497  06037930301                  75313.0           310300.0
# 4576  06037930301                  75313.0           310300.0
#
#       per_capita_income
# 3792            25714.0
# 3851            25714.0
# 4495            25714.0
# 4497            25714.0
# 4576            25714.0

# %%
sabs_tract_income .shape
# Out:
# (28408, 19)

# %% [markdown]
# # Group by

# %%
sabs_tract_income.groupby(by='GEOID').count()
# Out:
#              SrcName  ncessch  schnam  leaid  gslo  gshi  defacto  stAbbrev  \
# GEOID
# 06001400100        3        5       5      5     5     5        5         5
# 06001400200        1        3       3      3     3     3        3         3
# 06001400300        1        2       2      2     2     2        2         2
# 06001400400        1        3       3      3     3     3        3         3
# 06001400500        1        3       3      3     3     3        3         3
# ...              ...      ...     ...    ...   ...   ...      ...       ...
# 06115040800        0        3       3      3     3     3        3         3
# 06115040901        2        4       4      4     4     4        4         4
# 06115040902        1        2       2      2     2     2        2         2
# 06115041000        3        8       8      8     8     8        8         8
# 06115041100        1        4       4      4     4     4        4         4
#
#              openEnroll  Shape_Leng  Shape_Area  level  MultiBdy  geometry  \
# GEOID
# 06001400100           5           5           5      5         5         5
# 06001400200           3           3           3      3         3         3
# 06001400300           2           2           2      2         2         2
# 06001400400           3           3           3      3         3         3
# 06001400500           3           3           3      3         3         3
# ...                 ...         ...         ...    ...       ...       ...
# 06115040800           3           3           3      3         3         3
# 06115040901           4           4           4      4         4         4
# 06115040902           2           2           2      2         2         2
# 06115041000           8           8           8      8         8         8
# 06115041100           4           4           4      4         4         4
#
#              index_right  median_household_income  median_home_value  \
# GEOID
# 06001400100            5                        5                  5
# 06001400200            3                        3                  3
# 06001400300            2                        2                  2
# 06001400400            3                        3                  3
# 06001400500            3                        3                  3
# ...                  ...                      ...                ...
# 06115040800            3                        3                  3
# 06115040901            4                        4                  4
# 06115040902            2                        2                  0
# 06115041000            8                        8                  8
# 06115041100            4                        4                  4
#
#              per_capita_income
# GEOID
# 06001400100                  5
# 06001400200                  3
# 06001400300                  2
# 06001400400                  3
# 06001400500                  3
# ...                        ...
# 06115040800                  3
# 06115040901                  4
# 06115040902                  2
# 06115041000                  8
# 06115041100                  4
#
# [7753 rows x 18 columns]

# %%
tract_income.merge(sabs_tract_income.groupby(by='GEOID').count()['index_right'], on='GEOID')
# Out:
#             GEOID  median_household_income  median_home_value  \
# 0     06037554001                  55703.0           450200.0
# 1     06037554002                  56452.0           461200.0
# 2     06037554101                  42969.0           453200.0
# 3     06037554103                  81480.0           460200.0
# 4     06037554104                  63625.0           464800.0
# ...           ...                      ...                ...
# 7748  06115040800                  69159.0           254500.0
# 7749  06115040901                  57969.0           205000.0
# 7750  06115040902                  45250.0                NaN
# 7751  06115041000                  83194.0           327200.0
# 7752  06115041100                  45434.0           205500.0
#
#       per_capita_income                                           geometry  \
# 0               23331.0  POLYGON ((5987925.784 2275112.258, 5988249.105...
# 1               22520.0  POLYGON ((5987299.089 2275049.015, 5987348.882...
# 2               19127.0  POLYGON ((5992628.264 2276367.468, 5992690.382...
# 3               34880.0  POLYGON ((5992635.820 2276956.239, 5992710.707...
# 4               20344.0  POLYGON ((5993599.563 2274986.574, 5993703.488...
# ...                 ...                                                ...
# 7748            32816.0  POLYGON ((5058959.284 4180341.579, 5059024.590...
# 7749            25904.0  POLYGON ((5041586.069 4219922.530, 5041642.867...
# 7750            19183.0  POLYGON ((5071766.110 4217339.958, 5071993.551...
# 7751            39049.0  POLYGON ((5028575.474 4260876.310, 5028615.848...
# 7752            28558.0  POLYGON ((5105889.350 4303734.816, 5105901.755...
#
#       index_right
# 0               2
# 1               1
# 2               1
# 3               1
# 4               1
# ...           ...
# 7748            3
# 7749            4
# 7750            2
# 7751            8
# 7752            4
#
# [7753 rows x 6 columns]

# %%
tract_income.merge(sabs_tract_income.groupby(by='GEOID').count()['index_right'], on='GEOID', how='left')
# Out:
#             GEOID  median_household_income  median_home_value  \
# 0     06037554001                  55703.0           450200.0
# 1     06037554002                  56452.0           461200.0
# 2     06037554101                  42969.0           453200.0
# 3     06037554103                  81480.0           460200.0
# 4     06037554104                  63625.0           464800.0
# ...           ...                      ...                ...
# 8052  06115040800                  69159.0           254500.0
# 8053  06115040901                  57969.0           205000.0
# 8054  06115040902                  45250.0                NaN
# 8055  06115041000                  83194.0           327200.0
# 8056  06115041100                  45434.0           205500.0
#
#       per_capita_income                                           geometry  \
# 0               23331.0  POLYGON ((5987925.784 2275112.258, 5988249.105...
# 1               22520.0  POLYGON ((5987299.089 2275049.015, 5987348.882...
# 2               19127.0  POLYGON ((5992628.264 2276367.468, 5992690.382...
# 3               34880.0  POLYGON ((5992635.820 2276956.239, 5992710.707...
# 4               20344.0  POLYGON ((5993599.563 2274986.574, 5993703.488...
# ...                 ...                                                ...
# 8052            32816.0  POLYGON ((5058959.284 4180341.579, 5059024.590...
# 8053            25904.0  POLYGON ((5041586.069 4219922.530, 5041642.867...
# 8054            19183.0  POLYGON ((5071766.110 4217339.958, 5071993.551...
# 8055            39049.0  POLYGON ((5028575.474 4260876.310, 5028615.848...
# 8056            28558.0  POLYGON ((5105889.350 4303734.816, 5105901.755...
#
#       index_right
# 0             2.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0
# ...           ...
# 8052          3.0
# 8053          4.0
# 8054          2.0
# 8055          8.0
# 8056          4.0
#
# [8057 rows x 6 columns]

# %%
tract_income.shape
# Out:
# (8057, 5)

# %%
tract_income.merge(sabs_tract_income.groupby(by='GEOID').count()['index_right'], on='GEOID', how='left').fillna(0)
# Out:
#             GEOID  median_household_income  median_home_value  \
# 0     06037554001                  55703.0           450200.0
# 1     06037554002                  56452.0           461200.0
# 2     06037554101                  42969.0           453200.0
# 3     06037554103                  81480.0           460200.0
# 4     06037554104                  63625.0           464800.0
# ...           ...                      ...                ...
# 8052  06115040800                  69159.0           254500.0
# 8053  06115040901                  57969.0           205000.0
# 8054  06115040902                  45250.0                0.0
# 8055  06115041000                  83194.0           327200.0
# 8056  06115041100                  45434.0           205500.0
#
#       per_capita_income                                           geometry  \
# 0               23331.0  POLYGON ((5987925.784 2275112.258, 5988249.105...
# 1               22520.0  POLYGON ((5987299.089 2275049.015, 5987348.882...
# 2               19127.0  POLYGON ((5992628.264 2276367.468, 5992690.382...
# 3               34880.0  POLYGON ((5992635.820 2276956.239, 5992710.707...
# 4               20344.0  POLYGON ((5993599.563 2274986.574, 5993703.488...
# ...                 ...                                                ...
# 8052            32816.0  POLYGON ((5058959.284 4180341.579, 5059024.590...
# 8053            25904.0  POLYGON ((5041586.069 4219922.530, 5041642.867...
# 8054            19183.0  POLYGON ((5071766.110 4217339.958, 5071993.551...
# 8055            39049.0  POLYGON ((5028575.474 4260876.310, 5028615.848...
# 8056            28558.0  POLYGON ((5105889.350 4303734.816, 5105901.755...
#
#       index_right
# 0             2.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0
# ...           ...
# 8052          3.0
# 8053          4.0
# 8054          2.0
# 8055          8.0
# 8056          4.0
#
# [8057 rows x 6 columns]

# %%
tract_income.merge(sabs_tract_income.groupby(by='GEOID').count()['index_right'], on='GEOID', how='left').fillna(0).rename(columns={'index_right':'sabs'})
# Out:
#             GEOID  median_household_income  median_home_value  \
# 0     06037554001                  55703.0           450200.0
# 1     06037554002                  56452.0           461200.0
# 2     06037554101                  42969.0           453200.0
# 3     06037554103                  81480.0           460200.0
# 4     06037554104                  63625.0           464800.0
# ...           ...                      ...                ...
# 8052  06115040800                  69159.0           254500.0
# 8053  06115040901                  57969.0           205000.0
# 8054  06115040902                  45250.0                0.0
# 8055  06115041000                  83194.0           327200.0
# 8056  06115041100                  45434.0           205500.0
#
#       per_capita_income                                           geometry  \
# 0               23331.0  POLYGON ((5987925.784 2275112.258, 5988249.105...
# 1               22520.0  POLYGON ((5987299.089 2275049.015, 5987348.882...
# 2               19127.0  POLYGON ((5992628.264 2276367.468, 5992690.382...
# 3               34880.0  POLYGON ((5992635.820 2276956.239, 5992710.707...
# 4               20344.0  POLYGON ((5993599.563 2274986.574, 5993703.488...
# ...                 ...                                                ...
# 8052            32816.0  POLYGON ((5058959.284 4180341.579, 5059024.590...
# 8053            25904.0  POLYGON ((5041586.069 4219922.530, 5041642.867...
# 8054            19183.0  POLYGON ((5071766.110 4217339.958, 5071993.551...
# 8055            39049.0  POLYGON ((5028575.474 4260876.310, 5028615.848...
# 8056            28558.0  POLYGON ((5105889.350 4303734.816, 5105901.755...
#
#       sabs
# 0      2.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
# ...    ...
# 8052   3.0
# 8053   4.0
# 8054   2.0
# 8055   8.0
# 8056   4.0
#
# [8057 rows x 6 columns]

# %%
ca_tract_sabs_income = tract_income.merge(sabs_tract_income.groupby(by='GEOID').count()['index_right'], on='GEOID', how='left').fillna(0).rename(columns={'index_right':'sabs'})

# %%
ca_tract_sabs_income
# Out:
#             GEOID  median_household_income  median_home_value  \
# 0     06037554001                  55703.0           450200.0
# 1     06037554002                  56452.0           461200.0
# 2     06037554101                  42969.0           453200.0
# 3     06037554103                  81480.0           460200.0
# 4     06037554104                  63625.0           464800.0
# ...           ...                      ...                ...
# 8052  06115040800                  69159.0           254500.0
# 8053  06115040901                  57969.0           205000.0
# 8054  06115040902                  45250.0                0.0
# 8055  06115041000                  83194.0           327200.0
# 8056  06115041100                  45434.0           205500.0
#
#       per_capita_income                                           geometry  \
# 0               23331.0  POLYGON ((5987925.784 2275112.258, 5988249.105...
# 1               22520.0  POLYGON ((5987299.089 2275049.015, 5987348.882...
# 2               19127.0  POLYGON ((5992628.264 2276367.468, 5992690.382...
# 3               34880.0  POLYGON ((5992635.820 2276956.239, 5992710.707...
# 4               20344.0  POLYGON ((5993599.563 2274986.574, 5993703.488...
# ...                 ...                                                ...
# 8052            32816.0  POLYGON ((5058959.284 4180341.579, 5059024.590...
# 8053            25904.0  POLYGON ((5041586.069 4219922.530, 5041642.867...
# 8054            19183.0  POLYGON ((5071766.110 4217339.958, 5071993.551...
# 8055            39049.0  POLYGON ((5028575.474 4260876.310, 5028615.848...
# 8056            28558.0  POLYGON ((5105889.350 4303734.816, 5105901.755...
#
#       sabs
# 0      2.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
# ...    ...
# 8052   3.0
# 8053   4.0
# 8054   2.0
# 8055   8.0
# 8056   4.0
#
# [8057 rows x 6 columns]

# %%
ca_tract_sabs_income.shape
# Out:
# (8057, 6)

# %%
ca_tract_sabs_income['median_household_income'].mean()
# Out:
# 76468.29700881221

# %%
ca_tract_sabs_income['median_household_income'].median()
# Out:
# 69055.0

# %%
ca_tract_sabs_income.describe()
# Out:
#        median_household_income  median_home_value  per_capita_income  \
# count              8057.000000       8.057000e+03        8057.000000
# mean              76468.297009       5.337811e+05       35683.279881
# std               38375.304794       3.631056e+05       21498.612211
# min                   0.000000       0.000000e+00           0.000000
# 25%               48924.000000       3.052000e+05       20496.000000
# 50%               69055.000000       4.472000e+05       30506.000000
# 75%               96066.000000       6.709000e+05       44889.000000
# max              250001.000000       2.000001e+06      171298.000000
#
#               sabs
# count  8057.000000
# mean      3.525878
# std       3.141461
# min       0.000000
# 25%       1.000000
# 50%       2.000000
# 75%       4.000000
# max      26.000000

# %% [markdown]
# # Riverside

# %%
riverside = ca_tract_sabs_income[ca_tract_sabs_income.GEOID.str.startswith('06065')]

# filter the GEOID column to riverside only

# %%
riverside
# Out:
#             GEOID  median_household_income  median_home_value  \
# 6045  06065043252                 123032.0           478400.0
# 6046  06065043254                  81939.0           354500.0
# 6047  06065043256                  90175.0           370800.0
# 6048  06065043257                 118041.0           571600.0
# 6049  06065043262                 105190.0           420400.0
# ...           ...                      ...                ...
# 7984  06065043244                  87873.0           438100.0
# 7985  06065043246                 106294.0           500800.0
# 7986  06065043247                 110227.0           431600.0
# 7987  06065043248                 115625.0           458100.0
# 7988  06065043250                  85583.0           410800.0
#
#       per_capita_income                                           geometry  \
# 6045            38218.0  POLYGON ((6300069.665 2111924.118, 6300099.846...
# 6046            30557.0  POLYGON ((6256505.532 2109427.087, 6256517.353...
# 6047            28609.0  POLYGON ((6302033.793 2119457.866, 6302083.922...
# 6048            36308.0  POLYGON ((6303612.173 2107665.775, 6304427.770...
# 6049            40419.0  POLYGON ((6295070.451 2129495.784, 6295073.799...
# ...                 ...                                                ...
# 7984            31403.0  POLYGON ((6289367.120 2142136.136, 6289399.168...
# 7985            40089.0  POLYGON ((6304318.656 2133618.798, 6304353.586...
# 7986            29704.0  POLYGON ((6290462.295 2146030.218, 6290498.075...
# 7987            35508.0  POLYGON ((6303712.339 2115049.220, 6303717.146...
# 7988            34472.0  POLYGON ((6293603.200 2117808.116, 6293802.198...
#
#       sabs
# 6045   1.0
# 6046   5.0
# 6047   2.0
# 6048   4.0
# 6049   1.0
# ...    ...
# 7984   2.0
# 7985   1.0
# 7986   2.0
# 7987   1.0
# 7988   2.0
#
# [453 rows x 6 columns]

# %%
riverside.describe()
# Out:
#        median_household_income  median_home_value  per_capita_income  \
# count               453.000000         453.000000         453.000000
# mean              65538.377483      318012.362031       27846.843267
# std               26131.282509      134385.912817       13471.470265
# min                   0.000000           0.000000           0.000000
# 25%               44826.000000      236600.000000       18557.000000
# 50%               61814.000000      302900.000000       25155.000000
# 75%               82639.000000      384100.000000       33501.000000
# max              148667.000000      985300.000000      103854.000000
#
#              sabs
# count  453.000000
# mean     1.997792
# std      1.275187
# min      0.000000
# 25%      1.000000
# 50%      2.000000
# 75%      2.000000
# max     10.000000

# %%
ca_tract_sabs_income.describe()
# Out:
#        median_household_income  median_home_value  per_capita_income  \
# count              8057.000000       8.057000e+03        8057.000000
# mean              76468.297009       5.337811e+05       35683.279881
# std               38375.304794       3.631056e+05       21498.612211
# min                   0.000000       0.000000e+00           0.000000
# 25%               48924.000000       3.052000e+05       20496.000000
# 50%               69055.000000       4.472000e+05       30506.000000
# 75%               96066.000000       6.709000e+05       44889.000000
# max              250001.000000       2.000001e+06      171298.000000
#
#               sabs
# count  8057.000000
# mean      3.525878
# std       3.141461
# min       0.000000
# 25%       1.000000
# 50%       2.000000
# 75%       4.000000
# max      26.000000

# %% [markdown]
# # **Visualizations**

# %%
riverside.plot(figsize=(15,15))
# Out:
# <AxesSubplot:>

# %%
riverside.plot(column='median_household_income', scheme='equalinterval', k=5, legend=True, figsize=(15,15))
# Out:
# <AxesSubplot:>

# %%
riverside.plot(column='median_household_income', scheme='Quantiles', k=5, legend=True, figsize=(15,15))
# Out:
# <AxesSubplot:>

# %%
riverside.plot(column='median_home_value', scheme='equalinterval', k=5, legend=True, figsize=(15,15))
# Out:
# <AxesSubplot:>

# %%
riverside.plot(column='median_home_value', scheme='quantiles', k=5, legend=True, figsize=(15,15))
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data=riverside, x="median_household_income", y="median_home_value")
# Out:
# <AxesSubplot:xlabel='median_household_income', ylabel='median_home_value'>
