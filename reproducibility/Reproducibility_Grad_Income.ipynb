# %%
import pandas

# %%
import seaborn as sns
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
from geopandas_view import view
plt.rcParams['figure.figsize'] = [20,10]

# %%
graduation = pandas.read_parquet('correctgradrates.parquet')

# %%
graduation.shape
# Out:
# (58, 7)

# %%
dropout = pandas.read_parquet('dropout_count.parquet')

# %%
dropout.head()
# Out:
#             Dropout_Count
# CountyName
# Alameda           67080.0
# Amador              336.0
# Butte             12754.0
# Calaveras           774.0
# Colusa              820.0

# %%
dropout.shape
# Out:
# (58, 1)

# %%
grad_rates=dropout.merge(graduation,left_on="CountyName",right_on="CountyName")

# %%
grad_rates.head()
# Out:
#             Dropout_Count    Unnamed: 0  Unnamed: 0.1  CountyCode  \
# CountyName
# Alameda           67080.0  55058.786260  55058.786260         1.0
# Amador              336.0  46067.993902  46067.993902         3.0
# Butte             12754.0  51652.976656  51652.976656         4.0
# Calaveras           774.0  48949.265722  48949.265722         5.0
# Colusa              820.0  44884.890925  44884.890925         6.0
#
#             DistrictCode     SchoolCode  Regular HS Diploma Graduates (Rate)  \
# CountyName
# Alameda     58955.743928  214044.350660                            80.133171
# Amador      51356.797834  231815.176895                            80.229825
# Butte       52482.102397  463580.839506                            78.057168
# Calaveras   46217.943831  814737.532598                            87.612575
# Colusa      55662.107692  367130.161538                            89.476074
#
#             Dropoutrate
# CountyName
# Alameda       10.740965
# Amador         3.787719
# Butte         15.140088
# Calaveras      5.551497
# Colusa         7.255215

# %%
grad_rates.shape
# Out:
# (58, 8)

# %%
grad_rates.head()
# Out:
#             Dropout_Count    Unnamed: 0  Unnamed: 0.1  CountyCode  \
# CountyName
# Alameda           67080.0  55058.786260  55058.786260         1.0
# Amador              336.0  46067.993902  46067.993902         3.0
# Butte             12754.0  51652.976656  51652.976656         4.0
# Calaveras           774.0  48949.265722  48949.265722         5.0
# Colusa              820.0  44884.890925  44884.890925         6.0
#
#             DistrictCode     SchoolCode  Regular HS Diploma Graduates (Rate)  \
# CountyName
# Alameda     58955.743928  214044.350660                            80.133171
# Amador      51356.797834  231815.176895                            80.229825
# Butte       52482.102397  463580.839506                            78.057168
# Calaveras   46217.943831  814737.532598                            87.612575
# Colusa      55662.107692  367130.161538                            89.476074
#
#             Dropoutrate
# CountyName
# Alameda       10.740965
# Amador         3.787719
# Butte         15.140088
# Calaveras      5.551497
# Colusa         7.255215

# %%
graduation=graduation.reset_index()

# %%
from geosnap import datasets

# %%
counties=datasets.counties()

# %%
fips=pandas.read_csv("https://raw.githubusercontent.com/kjhealy/us-county/master/data/census/fips-by-state.csv",converters={"fips":str},encoding="latin1")

# %%
counties=counties.merge(fips,left_on="geoid",right_on="fips")

# %%
counties.name=counties.name.apply(lambda x:x[:-7])

# %%
counties=counties.merge(graduation, left_on="name", right_on="CountyName",how="right")

# %%
counties=counties[counties.state=="CA"]

# %%
counties.head()
# Out:
#    geoid                                           geometry   fips       name  \
# 0  06001  POLYGON ((-122.28088 37.70723, -122.28178 37.7...  06001    Alameda
# 1  06005  POLYGON ((-121.02729 38.48136, -121.02729 38.4...  06005     Amador
# 3  06007  POLYGON ((-121.85650 39.53358, -121.85638 39.5...  06007      Butte
# 5  06009  POLYGON ((-120.63093 38.34110, -120.63057 38.3...  06009  Calaveras
# 6  06011  POLYGON ((-122.08018 39.41420, -122.07996 39.4...  06011     Colusa
#
#   state CountyName    Unnamed: 0  Unnamed: 0.1  CountyCode  DistrictCode  \
# 0    CA    Alameda  55058.786260  55058.786260         1.0  58955.743928
# 1    CA     Amador  46067.993902  46067.993902         3.0  51356.797834
# 3    CA      Butte  51652.976656  51652.976656         4.0  52482.102397
# 5    CA  Calaveras  48949.265722  48949.265722         5.0  46217.943831
# 6    CA     Colusa  44884.890925  44884.890925         6.0  55662.107692
#
#       SchoolCode  Regular HS Diploma Graduates (Rate)  Dropoutrate
# 0  214044.350660                            80.133171    10.740965
# 1  231815.176895                            80.229825     3.787719
# 3  463580.839506                            78.057168    15.140088
# 5  814737.532598                            87.612575     5.551497
# 6  367130.161538                            89.476074     7.255215

# %%
counties['fips'] = [v[2:] for v in counties.fips.values]

# %%
counties.head()
# Out:
#    geoid                                           geometry fips       name  \
# 0  06001  POLYGON ((-122.28088 37.70723, -122.28178 37.7...  001    Alameda
# 1  06005  POLYGON ((-121.02729 38.48136, -121.02729 38.4...  005     Amador
# 3  06007  POLYGON ((-121.85650 39.53358, -121.85638 39.5...  007      Butte
# 5  06009  POLYGON ((-120.63093 38.34110, -120.63057 38.3...  009  Calaveras
# 6  06011  POLYGON ((-122.08018 39.41420, -122.07996 39.4...  011     Colusa
#
#   state CountyName    Unnamed: 0  Unnamed: 0.1  CountyCode  DistrictCode  \
# 0    CA    Alameda  55058.786260  55058.786260         1.0  58955.743928
# 1    CA     Amador  46067.993902  46067.993902         3.0  51356.797834
# 3    CA      Butte  51652.976656  51652.976656         4.0  52482.102397
# 5    CA  Calaveras  48949.265722  48949.265722         5.0  46217.943831
# 6    CA     Colusa  44884.890925  44884.890925         6.0  55662.107692
#
#       SchoolCode  Regular HS Diploma Graduates (Rate)  Dropoutrate
# 0  214044.350660                            80.133171    10.740965
# 1  231815.176895                            80.229825     3.787719
# 3  463580.839506                            78.057168    15.140088
# 5  814737.532598                            87.612575     5.551497
# 6  367130.161538                            89.476074     7.255215

# %%
counties.fips=counties.fips.astype(float)

# %%
counties.shape
# Out:
# (57, 13)

# %%
counties.columns
# Out:
# Index(['geoid', 'geometry', 'fips', 'name', 'state', 'CountyName',
#        'Unnamed: 0', 'Unnamed: 0.1', 'CountyCode', 'DistrictCode',
#        'SchoolCode', 'Regular HS Diploma Graduates (Rate)', 'Dropoutrate'],
#       dtype='object')

# %%
counties.rename(columns={"Regular HS Diploma Graduates (Rate)":"hsgradrate"},inplace=True)

# %% [markdown]
# ## Graduation Visuals

# %%
counties.plot(column='Dropoutrate', scheme='FisherJenks', k=5, legend=True, figsize=(15,15))
# Out:
# <AxesSubplot:>

# %%
counties.plot(column='hsgradrate', scheme='FisherJenks', k=5, legend=True, figsize=(15,15))
# Out:
# <AxesSubplot:>

# %%
counties.shape
# Out:
# (57, 13)

# %%
counties.head()
# Out:
#    geoid                                           geometry  fips       name  \
# 0  06001  POLYGON ((-122.28088 37.70723, -122.28178 37.7...   1.0    Alameda
# 1  06005  POLYGON ((-121.02729 38.48136, -121.02729 38.4...   5.0     Amador
# 3  06007  POLYGON ((-121.85650 39.53358, -121.85638 39.5...   7.0      Butte
# 5  06009  POLYGON ((-120.63093 38.34110, -120.63057 38.3...   9.0  Calaveras
# 6  06011  POLYGON ((-122.08018 39.41420, -122.07996 39.4...  11.0     Colusa
#
#   state CountyName    Unnamed: 0  Unnamed: 0.1  CountyCode  DistrictCode  \
# 0    CA    Alameda  55058.786260  55058.786260         1.0  58955.743928
# 1    CA     Amador  46067.993902  46067.993902         3.0  51356.797834
# 3    CA      Butte  51652.976656  51652.976656         4.0  52482.102397
# 5    CA  Calaveras  48949.265722  48949.265722         5.0  46217.943831
# 6    CA     Colusa  44884.890925  44884.890925         6.0  55662.107692
#
#       SchoolCode  hsgradrate  Dropoutrate
# 0  214044.350660   80.133171    10.740965
# 1  231815.176895   80.229825     3.787719
# 3  463580.839506   78.057168    15.140088
# 5  814737.532598   87.612575     5.551497
# 6  367130.161538   89.476074     7.255215

# %%
income = gpd.read_parquet('./income/ca_tract_incomes.parquet')

# %%
income.head()
# Out:
#          GEOID  median_household_income  median_home_value  per_capita_income  \
# 0  06037554001                  55703.0           450200.0            23331.0
# 1  06037554002                  56452.0           461200.0            22520.0
# 2  06037554101                  42969.0           453200.0            19127.0
# 3  06037554103                  81480.0           460200.0            34880.0
# 4  06037554104                  63625.0           464800.0            20344.0
#
#                                             geometry
# 0  POLYGON ((5987925.784 2275112.258, 5988249.105...
# 1  POLYGON ((5987299.089 2275049.015, 5987348.882...
# 2  POLYGON ((5992628.264 2276367.468, 5992690.382...
# 3  POLYGON ((5992635.820 2276956.239, 5992710.707...
# 4  POLYGON ((5993599.563 2274986.574, 5993703.488...

# %%
income["county"]=[code[2:5] for code in income.GEOID.values]

# %%
income.head()
# Out:
#          GEOID  median_household_income  median_home_value  per_capita_income  \
# 0  06037554001                  55703.0           450200.0            23331.0
# 1  06037554002                  56452.0           461200.0            22520.0
# 2  06037554101                  42969.0           453200.0            19127.0
# 3  06037554103                  81480.0           460200.0            34880.0
# 4  06037554104                  63625.0           464800.0            20344.0
#
#                                             geometry county
# 0  POLYGON ((5987925.784 2275112.258, 5988249.105...    037
# 1  POLYGON ((5987299.089 2275049.015, 5987348.882...    037
# 2  POLYGON ((5992628.264 2276367.468, 5992690.382...    037
# 3  POLYGON ((5992635.820 2276956.239, 5992710.707...    037
# 4  POLYGON ((5993599.563 2274986.574, 5993703.488...    037

# %%
countyincome_average=income.groupby(by='county').mean()

# %%
countyincome_average.shape
# Out:
# (58, 3)

# %%
countyincome_average.head()
# Out:
#         median_household_income  median_home_value  per_capita_income
# county
# 001                98936.975000      699858.432584       45224.541667
# 003                64688.000000      349000.000000       29041.000000
# 005                61656.444444      298988.888889       30229.777778
# 007                50684.764706      253241.176471       26936.000000
# 009                55489.900000      297550.000000       36696.600000

# %%
countyincome_average.columns
# Out:
# Index(['median_household_income', 'median_home_value', 'per_capita_income'], dtype='object')

# %%
countyincome_average.reset_index(level=0,inplace=True)

# %%
countyincome_average.head()
# Out:
#   county  median_household_income  median_home_value  per_capita_income
# 0    001             98936.975000      699858.432584       45224.541667
# 1    003             64688.000000      349000.000000       29041.000000
# 2    005             61656.444444      298988.888889       30229.777778
# 3    007             50684.764706      253241.176471       26936.000000
# 4    009             55489.900000      297550.000000       36696.600000

# %%
countyincome_average["county"] = countyincome_average["county"]
print(countyincome_average)
# Out:
#    county  median_household_income  median_home_value  per_capita_income
# 0     001             98936.975000       6.998584e+05       45224.541667
# 1     003             64688.000000       3.490000e+05       29041.000000
# 2     005             61656.444444       2.989889e+05       30229.777778
# 3     007             50684.764706       2.532412e+05       26936.000000
# 4     009             55489.900000       2.975500e+05       36696.600000
# 5     011             55385.200000       2.405400e+05       27744.800000
# 6     013            103459.053140       6.142169e+05       46677.198068
# 7     015             43263.714286       1.892143e+05       21846.285714
# 8     017             83436.166667       4.364024e+05       39484.595238
# 9     019             54711.323232       2.208549e+05       23676.623116
# 10    021             48764.833333       2.435833e+05       24863.833333
# 11    023             46979.566667       3.113767e+05       27085.133333
# 12    025             45908.032258       1.643333e+05       17672.967742
# 13    027             60352.833333       2.494000e+05       33389.833333
# 14    029             54320.979592       1.865386e+05       22669.662252
# 15    031             54878.520000       1.962750e+05       21502.333333
# 16    033             42818.933333       1.794667e+05       24808.666667
# 17    035             55812.888889       1.893778e+05       25984.000000
# 18    037             69678.021664       5.928213e+05       33067.378820
# 19    039             54063.347826       2.284000e+05       22437.782609
# 20    041            119366.981481       1.065433e+06       70905.527273
# 21    043             57468.166667       2.860000e+05       30395.333333
# 22    045             50086.400000       3.678200e+05       28039.600000
# 23    047             50327.204082       2.342571e+05       21938.714286
# 24    049             44837.750000       1.455250e+05       23629.250000
# 25    051             61643.000000       3.150667e+05       33432.666667
# 26    053             70830.868132       5.194352e+05       31382.184783
# 27    055             88618.384615       6.749436e+05       45330.225000
# 28    057             69013.800000       4.133600e+05       37980.550000
# 29    059             91467.853448       6.747577e+05       40986.111684
# 30    061             85704.023810       4.574179e+05       41748.869048
# 31    063             57092.000000       2.495000e+05       36653.857143
# 32    065             65829.013304       3.201324e+05       27908.451327
# 33    067             68249.520505       3.302080e+05       32239.763407
# 34    069             83712.909091       5.301545e+05       32770.636364
# 35    071             62086.306011       3.004248e+05       24123.432065
# 36    073             79566.183575       5.504709e+05       36655.217252
# 37    075            107117.787565       1.096610e+06       65057.430769
# 38    077             58955.338129       2.812580e+05       24888.410072
# 39    079             70661.461538       5.780667e+05       36319.792453
# 40    081            127676.064103       1.112854e+06       60611.935897
# 41    083             78198.298851       6.751675e+05       37456.459770
# 42    085            121594.505376       9.815321e+05       53235.231183
# 43    087             83925.288462       7.053115e+05       41488.519231
# 44    089             53342.208333       2.470688e+05       28524.833333
# 45    091             48125.000000       1.732000e+05       31972.000000
# 46    093             42071.000000       1.781786e+05       25723.357143
# 47    095             78944.265957       3.694304e+05       33280.547368
# 48    097             78971.666667       5.793646e+05       41289.797980
# 49    099             56806.244681       2.576266e+05       24486.244681
# 50    101             58872.285714       2.554381e+05       26633.238095
# 51    103             43939.181818       2.000455e+05       23595.727273
# 52    105             37546.800000       2.826000e+05       27497.600000
# 53    107             46713.337662       1.843649e+05       20071.294872
# 54    109             55892.900000       2.822900e+05       31650.181818
# 55    111             88033.418605       5.653316e+05       37916.913295
# 56    113             69839.682927       4.531400e+05       34033.878049
# 57    115             50473.714286       1.959154e+05       22181.214286

# %%
countyincome_average.dtypes
# Out:
# county                      object
# median_household_income    float64
# median_home_value          float64
# per_capita_income          float64
# dtype: object

# %%
import numpy as np

# %%
countyincome_average.county=countyincome_average.county.astype(float)

# %%
countyincome_average.head()
# Out:
#    county  median_household_income  median_home_value  per_capita_income
# 0     1.0             98936.975000      699858.432584       45224.541667
# 1     3.0             64688.000000      349000.000000       29041.000000
# 2     5.0             61656.444444      298988.888889       30229.777778
# 3     7.0             50684.764706      253241.176471       26936.000000
# 4     9.0             55489.900000      297550.000000       36696.600000

# %%
countyincome_average.isna()
# Out:
#     county  median_household_income  median_home_value  per_capita_income
# 0    False                    False              False              False
# 1    False                    False              False              False
# 2    False                    False              False              False
# 3    False                    False              False              False
# 4    False                    False              False              False
# 5    False                    False              False              False
# 6    False                    False              False              False
# 7    False                    False              False              False
# 8    False                    False              False              False
# 9    False                    False              False              False
# 10   False                    False              False              False
# 11   False                    False              False              False
# 12   False                    False              False              False
# 13   False                    False              False              False
# 14   False                    False              False              False
# 15   False                    False              False              False
# 16   False                    False              False              False
# 17   False                    False              False              False
# 18   False                    False              False              False
# 19   False                    False              False              False
# 20   False                    False              False              False
# 21   False                    False              False              False
# 22   False                    False              False              False
# 23   False                    False              False              False
# 24   False                    False              False              False
# 25   False                    False              False              False
# 26   False                    False              False              False
# 27   False                    False              False              False
# 28   False                    False              False              False
# 29   False                    False              False              False
# 30   False                    False              False              False
# 31   False                    False              False              False
# 32   False                    False              False              False
# 33   False                    False              False              False
# 34   False                    False              False              False
# 35   False                    False              False              False
# 36   False                    False              False              False
# 37   False                    False              False              False
# 38   False                    False              False              False
# 39   False                    False              False              False
# 40   False                    False              False              False
# 41   False                    False              False              False
# 42   False                    False              False              False
# 43   False                    False              False              False
# 44   False                    False              False              False
# 45   False                    False              False              False
# 46   False                    False              False              False
# 47   False                    False              False              False
# 48   False                    False              False              False
# 49   False                    False              False              False
# 50   False                    False              False              False
# 51   False                    False              False              False
# 52   False                    False              False              False
# 53   False                    False              False              False
# 54   False                    False              False              False
# 55   False                    False              False              False
# 56   False                    False              False              False
# 57   False                    False              False              False

# %%
avg_countyinc_grad=counties.merge(countyincome_average, left_on="fips", right_on="county", how="left")

# %%
avg_countyinc_grad.head()
# Out:
#    geoid                                           geometry  fips       name  \
# 0  06001  POLYGON ((-122.28088 37.70723, -122.28178 37.7...   1.0    Alameda
# 1  06005  POLYGON ((-121.02729 38.48136, -121.02729 38.4...   5.0     Amador
# 2  06007  POLYGON ((-121.85650 39.53358, -121.85638 39.5...   7.0      Butte
# 3  06009  POLYGON ((-120.63093 38.34110, -120.63057 38.3...   9.0  Calaveras
# 4  06011  POLYGON ((-122.08018 39.41420, -122.07996 39.4...  11.0     Colusa
#
#   state CountyName    Unnamed: 0  Unnamed: 0.1  CountyCode  DistrictCode  \
# 0    CA    Alameda  55058.786260  55058.786260         1.0  58955.743928
# 1    CA     Amador  46067.993902  46067.993902         3.0  51356.797834
# 2    CA      Butte  51652.976656  51652.976656         4.0  52482.102397
# 3    CA  Calaveras  48949.265722  48949.265722         5.0  46217.943831
# 4    CA     Colusa  44884.890925  44884.890925         6.0  55662.107692
#
#       SchoolCode  hsgradrate  Dropoutrate  county  median_household_income  \
# 0  214044.350660   80.133171    10.740965     1.0             98936.975000
# 1  231815.176895   80.229825     3.787719     5.0             61656.444444
# 2  463580.839506   78.057168    15.140088     7.0             50684.764706
# 3  814737.532598   87.612575     5.551497     9.0             55489.900000
# 4  367130.161538   89.476074     7.255215    11.0             55385.200000
#
#    median_home_value  per_capita_income
# 0      699858.432584       45224.541667
# 1      298988.888889       30229.777778
# 2      253241.176471       26936.000000
# 3      297550.000000       36696.600000
# 4      240540.000000       27744.800000

# %%
avg_countyinc_grad.to_parquet('avg_income.parquet')
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: this is an initial implementation of Parquet/Feather file support and associated metadata.  This is tracking version 0.1.0 of the metadata specification at https://github.com/geopandas/geo-arrow-spec
#
# This metadata specification does not yet make stability promises.  We do not yet recommend using this in a production setting unless you are able to rewrite your Parquet/Feather files.
#
# To further ignore this warning, you can do:
# import warnings; warnings.filterwarnings('ignore', message='.*initial implementation of Parquet.*')
#   """Entry point for launching an IPython kernel.

# %%
avg_countyinc_grad.head()
# Out:
#    geoid                                           geometry  fips       name  \
# 0  06001  POLYGON ((-122.28088 37.70723, -122.28178 37.7...   1.0    Alameda
# 1  06005  POLYGON ((-121.02729 38.48136, -121.02729 38.4...   5.0     Amador
# 2  06007  POLYGON ((-121.85650 39.53358, -121.85638 39.5...   7.0      Butte
# 3  06009  POLYGON ((-120.63093 38.34110, -120.63057 38.3...   9.0  Calaveras
# 4  06011  POLYGON ((-122.08018 39.41420, -122.07996 39.4...  11.0     Colusa
#
#   state CountyName    Unnamed: 0  Unnamed: 0.1  CountyCode  DistrictCode  \
# 0    CA    Alameda  55058.786260  55058.786260         1.0  58955.743928
# 1    CA     Amador  46067.993902  46067.993902         3.0  51356.797834
# 2    CA      Butte  51652.976656  51652.976656         4.0  52482.102397
# 3    CA  Calaveras  48949.265722  48949.265722         5.0  46217.943831
# 4    CA     Colusa  44884.890925  44884.890925         6.0  55662.107692
#
#       SchoolCode  hsgradrate  Dropoutrate  county  median_household_income  \
# 0  214044.350660   80.133171    10.740965     1.0             98936.975000
# 1  231815.176895   80.229825     3.787719     5.0             61656.444444
# 2  463580.839506   78.057168    15.140088     7.0             50684.764706
# 3  814737.532598   87.612575     5.551497     9.0             55489.900000
# 4  367130.161538   89.476074     7.255215    11.0             55385.200000
#
#    median_home_value  per_capita_income
# 0      699858.432584       45224.541667
# 1      298988.888889       30229.777778
# 2      253241.176471       26936.000000
# 3      297550.000000       36696.600000
# 4      240540.000000       27744.800000

# %%
latino_county = pandas.read_parquet('latino.parquet')

# %%
latino_county.head()
# Out:
#           Latino
# county
# 001     369061.0
# 003        105.0
# 005       5132.0
# 007      36358.0
# 009       5297.0

# %%
latino_county.reset_index(level=0,inplace=True)

# %%
latino_county['county'] = [v[1:] for v in latino_county.county.values]

# %%
latino_county.head()
# Out:
#   county    Latino
# 0     01  369061.0
# 1     03     105.0
# 2     05    5132.0
# 3     07   36358.0
# 4     09    5297.0

# %%
latino_county.dtypes
# Out:
# county     object
# Latino    float64
# dtype: object

# %%
latino_county["county"]=latino_county["county"].astype(float)

# %%
finalvisual=latino_county.merge(avg_countyinc_grad, left_on="county", right_on="fips", how="left")

# %%
finalvisual.head()
# Out:
#    county_x    Latino  geoid  \
# 0       1.0  369061.0  06001
# 1       3.0     105.0    NaN
# 2       5.0    5132.0  06005
# 3       7.0   36358.0  06007
# 4       9.0    5297.0  06009
#
#                                             geometry  fips       name state  \
# 0  POLYGON ((-122.28088 37.70723, -122.28178 37.7...   1.0    Alameda    CA
# 1                                               None   NaN        NaN   NaN
# 2  POLYGON ((-121.02729 38.48136, -121.02729 38.4...   5.0     Amador    CA
# 3  POLYGON ((-121.85650 39.53358, -121.85638 39.5...   7.0      Butte    CA
# 4  POLYGON ((-120.63093 38.34110, -120.63057 38.3...   9.0  Calaveras    CA
#
#   CountyName    Unnamed: 0  Unnamed: 0.1  CountyCode  DistrictCode  \
# 0    Alameda  55058.786260  55058.786260         1.0  58955.743928
# 1        NaN           NaN           NaN         NaN           NaN
# 2     Amador  46067.993902  46067.993902         3.0  51356.797834
# 3      Butte  51652.976656  51652.976656         4.0  52482.102397
# 4  Calaveras  48949.265722  48949.265722         5.0  46217.943831
#
#       SchoolCode  hsgradrate  Dropoutrate  county_y  median_household_income  \
# 0  214044.350660   80.133171    10.740965       1.0             98936.975000
# 1            NaN         NaN          NaN       NaN                      NaN
# 2  231815.176895   80.229825     3.787719       5.0             61656.444444
# 3  463580.839506   78.057168    15.140088       7.0             50684.764706
# 4  814737.532598   87.612575     5.551497       9.0             55489.900000
#
#    median_home_value  per_capita_income
# 0      699858.432584       45224.541667
# 1                NaN                NaN
# 2      298988.888889       30229.777778
# 3      253241.176471       26936.000000
# 4      297550.000000       36696.600000

# %% [markdown]
# ## Income Visuals

# %%
avg_countyinc_grad.plot(column='median_household_income', scheme='FisherJenks', k=5, legend=True, figsize=(15,15))
# Out:
# <AxesSubplot:>

# %%
avg_countyinc_grad.plot(column='per_capita_income', scheme='FisherJenks', k=5, legend=True, figsize=(15,15))
# Out:
# <AxesSubplot:>

# %%
avg_countyinc_grad.plot(column='median_household_income', scheme='FisherJenks', k=5, legend=True, figsize=(15,15))
# Out:
# <AxesSubplot:>

# %% [raw]
# avg_countyinc_grad.plot(column='per_capita_income', scheme='FisherJenks', k=5, legend=True, figsize=(15,15))

# %%
avg_countyinc_grad.shape
# Out:
# (57, 17)

# %%
racevisuals = gpd.read_parquet('race_dem_rates.parquet')

# %%
racevisuals.head()
# Out:
#    GEOID              NAMELSAD     CountyName  \
# 0  06091         Sierra County         Sierra
# 1  06067     Sacramento County     Sacramento
# 2  06083  Santa Barbara County  Santa Barbara
# 3  06009      Calaveras County      Calaveras
# 4  06111        Ventura County        Ventura
#
#                                             geometry  total_mf_10_19  \
# 0  POLYGON ((-120.65559 39.69356, -120.65552 39.6...           294.0
# 1  POLYGON ((-121.18857 38.71431, -121.18731 38.7...        196932.0
# 2  MULTIPOLYGON (((-120.73429 34.90069, -120.7343...         64685.0
# 3  POLYGON ((-120.63093 38.34110, -120.63057 38.3...          4245.0
# 4  MULTIPOLYGON (((-119.32922 34.22784, -119.3292...        116814.0
#
#    median_household_income     white     black    amind     asian    nh_pi  \
# 0                  48125.0    2890.0       6.0     25.0       0.0      0.0
# 1               21635098.0  875793.0  149064.0  10340.0  235474.0  16715.0
# 2                6803252.0  344026.0    8626.0   4389.0   23863.0    814.0
# 3                 554899.0   41375.0     302.0    492.0     568.0    126.0
# 4               15141748.0  680197.0   14835.0   7069.0   61772.0   1771.0
#
#    two_or_more  total_pop  white_rate  black_rate  amind_rate  asian_rate  \
# 0          9.0     2930.0    0.986348    0.002048    0.008532    0.000000
# 1     107565.0  1510023.0    0.579987    0.098716    0.006848    0.155941
# 2      19996.0   443738.0    0.775291    0.019439    0.009891    0.053777
# 3       1825.0    45235.0    0.914668    0.006676    0.010877    0.012557
# 4      37561.0   848112.0    0.802013    0.017492    0.008335    0.072835
#
#    nh_pi_rate  two_or_more_rate
# 0    0.000000          0.003072
# 1    0.011069          0.071234
# 2    0.001834          0.045063
# 3    0.002785          0.040345
# 4    0.002088          0.044288

# %%
totalpop = racevisuals[['geometry','total_pop','GEOID']]

# %%
totalpop.head()
# Out:
#                                             geometry  total_pop  GEOID
# 0  POLYGON ((-120.65559 39.69356, -120.65552 39.6...     2930.0  06091
# 1  POLYGON ((-121.18857 38.71431, -121.18731 38.7...  1510023.0  06067
# 2  MULTIPOLYGON (((-120.73429 34.90069, -120.7343...   443738.0  06083
# 3  POLYGON ((-120.63093 38.34110, -120.63057 38.3...    45235.0  06009
# 4  MULTIPOLYGON (((-119.32922 34.22784, -119.3292...   848112.0  06111
