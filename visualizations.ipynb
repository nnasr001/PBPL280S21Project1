# %%
import seaborn as sns
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
from geopandas_view import view
plt.rcParams['figure.figsize'] = [20,10]

# %%
gpd.read_parquet("schoolcounties.parquet")
# Out:
#         geoid                                           geometry   fips  \
# 6       06059  POLYGON ((-117.98910 33.58579, -117.99067 33.5...  06059
# 14      06059  POLYGON ((-117.98910 33.58579, -117.99067 33.5...  06059
# 22      06059  POLYGON ((-117.98910 33.58579, -117.99067 33.5...  06059
# 30      06059  POLYGON ((-117.98910 33.58579, -117.99067 33.5...  06059
# 38      06059  POLYGON ((-117.98910 33.58579, -117.99067 33.5...  06059
# ...       ...                                                ...    ...
# 130648  06073  POLYGON ((-117.43743 33.17953, -117.44954 33.1...  06073
# 130649  06073  POLYGON ((-117.43743 33.17953, -117.44954 33.1...  06073
# 130650  06073  POLYGON ((-117.43743 33.17953, -117.44954 33.1...  06073
# 130651  06073  POLYGON ((-117.43743 33.17953, -117.44954 33.1...  06073
# 130652  06073  POLYGON ((-117.43743 33.17953, -117.44954 33.1...  06073
#
#              name state CountyName  ChronicAbsenteeismCount  \
# 6          Orange    CA     Orange                 470658.0
# 14         Orange    CA     Orange                 470658.0
# 22         Orange    CA     Orange                 470658.0
# 30         Orange    CA     Orange                 470658.0
# 38         Orange    CA     Orange                 470658.0
# ...           ...   ...        ...                      ...
# 130648  San Diego    CA  San Diego                 579235.0
# 130649  San Diego    CA  San Diego                 579235.0
# 130650  San Diego    CA  San Diego                 579235.0
# 130651  San Diego    CA  San Diego                 579235.0
# 130652  San Diego    CA  San Diego                 579235.0
#
#         CumulativeEnrollment  absentrate  Unnamed: 0  ...  \
# 6                  5351478.0    0.087949        4014  ...
# 14                 5351478.0    0.087949        4015  ...
# 22                 5351478.0    0.087949        4016  ...
# 30                 5351478.0    0.087949        4017  ...
# 38                 5351478.0    0.087949        4018  ...
# ...                      ...         ...         ...  ...
# 130648             5064892.0    0.114363      207542  ...
# 130649             5064892.0    0.114363      207543  ...
# 130650             5064892.0    0.114363      207544  ...
# 130651             5064892.0    0.114363      207545  ...
# 130652             5064892.0    0.114363      207546  ...
#
#        SPED Certificate (Count) SPED Certificate (Rate)  \
# 6                           147                     0.7
# 14                          263                     1.3
# 22                            *                       *
# 30                           72                     1.1
# 38                            9                     1.5
# ...                         ...                     ...
# 130648                        0                     0.0
# 130649                        0                     0.0
# 130650                        0                     0.0
# 130651                        0                     0.0
# 130652                        0                     0.0
#
#         GED Completer (Count)  GED Completer (Rate)  Other Transfer (Count)  \
# 6                           4                   0.0                      80
# 14                         21                   0.1                     155
# 22                          *                     *                       *
# 30                          1                   0.0                      16
# 38                          1                   0.2                       1
# ...                       ...                   ...                     ...
# 130648                      0                   0.0                       0
# 130649                      0                   0.0                       0
# 130650                      1                   6.3                       0
# 130651                      4                   4.8                       1
# 130652                      4                   4.3                       1
#
#        Other Transfer (Rate) Dropout (Count) Dropout (Rate)  \
# 6                        0.4             824            4.2
# 14                       0.8            1178            5.7
# 22                         *               *              *
# 30                       0.2             158            2.3
# 38                       0.2              51            8.2
# ...                      ...             ...            ...
# 130648                   0.0               1            5.0
# 130649                   0.0               1            5.6
# 130650                   0.0               1            6.3
# 130651                   1.2               5            6.0
# 130652                   1.1               6            6.5
#
#        Still Enrolled (Count) Still Enrolled (Rate)
# 6                         344                   1.8
# 14                        590                   2.9
# 22                          *                     *
# 30                         51                   0.8
# 38                         25                   4.0
# ...                       ...                   ...
# 130648                     12                  60.0
# 130649                      9                  50.0
# 130650                      8                  50.0
# 130651                     29                  34.9
# 130652                     32                  34.4
#
# [53688 rows x 43 columns]

# %%
schoolcounties = gpd.read_parquet("schoolcounties.parquet")

# %%
schoolcounties.head()
# Out:
#     geoid                                           geometry   fips    name  \
# 6   06059  POLYGON ((-117.98910 33.58579, -117.99067 33.5...  06059  Orange
# 14  06059  POLYGON ((-117.98910 33.58579, -117.99067 33.5...  06059  Orange
# 22  06059  POLYGON ((-117.98910 33.58579, -117.99067 33.5...  06059  Orange
# 30  06059  POLYGON ((-117.98910 33.58579, -117.99067 33.5...  06059  Orange
# 38  06059  POLYGON ((-117.98910 33.58579, -117.99067 33.5...  06059  Orange
#
#    state CountyName  ChronicAbsenteeismCount  CumulativeEnrollment  \
# 6     CA     Orange                 470658.0             5351478.0
# 14    CA     Orange                 470658.0             5351478.0
# 22    CA     Orange                 470658.0             5351478.0
# 30    CA     Orange                 470658.0             5351478.0
# 38    CA     Orange                 470658.0             5351478.0
#
#     absentrate  Unnamed: 0  ... SPED Certificate (Count)  \
# 6     0.087949        4014  ...                      147
# 14    0.087949        4015  ...                      263
# 22    0.087949        4016  ...                        *
# 30    0.087949        4017  ...                       72
# 38    0.087949        4018  ...                        9
#
#    SPED Certificate (Rate)  GED Completer (Count)  GED Completer (Rate)  \
# 6                      0.7                      4                   0.0
# 14                     1.3                     21                   0.1
# 22                       *                      *                     *
# 30                     1.1                      1                   0.0
# 38                     1.5                      1                   0.2
#
#     Other Transfer (Count) Other Transfer (Rate) Dropout (Count)  \
# 6                       80                   0.4             824
# 14                     155                   0.8            1178
# 22                       *                     *               *
# 30                      16                   0.2             158
# 38                       1                   0.2              51
#
#    Dropout (Rate) Still Enrolled (Count) Still Enrolled (Rate)
# 6             4.2                    344                   1.8
# 14            5.7                    590                   2.9
# 22              *                      *                     *
# 30            2.3                     51                   0.8
# 38            8.2                     25                   4.0
#
# [5 rows x 43 columns]
