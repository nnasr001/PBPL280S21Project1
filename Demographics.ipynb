# %%
import pandas

# %%
import pandas as pd

# %%
import geopandas as gpd

# %%
import matplotlib.pyplot as plt

# %%
import contextily as ctx

# %%
from geopandas_view import view

# %%
import geopandas

# %%
import quilt3
b = quilt3.Bucket("s3://spatial-ucr")
# list files
b.ls("census/demographic_profile/2018/")
# download
b.fetch("census/demographic_profile/2018/", "./2018/")
# Out:
# 100%|██████████| 3.23G/3.23G [00:24<00:00, 130MB/s]

# %%
b.fetch("census/demographic_profile/2018/acs_2018_X01_AGE_AND_SEX_tract.parquet", "./acs_2018_X01_AGE_AND_SEX_tract.parquet")
# Out:
# 100%|██████████| 23.2M/23.2M [00:09<00:00, 2.46MB/s]

# %%
tracts = pandas.read_parquet('./acs_2018_X01_AGE_AND_SEX_tract.parquet')

# %%
tracts.head()
# Out:
#                     B01001_001E  B01001_002E  B01001_003E  B01001_004E  \
# GEOID
# 14000US01001020100       1923.0        929.0         22.0         35.0
# 14000US01001020200       2028.0       1091.0         60.0        109.0
# 14000US01001020300       3476.0       1581.0         53.0        142.0
# 14000US01001020400       3831.0       1867.0        149.0        144.0
# 14000US01001020500       9883.0       4902.0        350.0        473.0
#
#                     B01001_005E  B01001_006E  B01001_007E  B01001_008E  \
# GEOID
# 14000US01001020100         67.0         83.0         58.0          6.0
# 14000US01001020200         51.0         46.0         50.0         16.0
# 14000US01001020300        155.0         43.0         32.0          5.0
# 14000US01001020400         86.0         40.0         37.0          9.0
# 14000US01001020500        220.0        309.0        107.0         17.0
#
#                     B01001_009E  B01001_010E  ...  B01002G_001E  B01002G_002E  \
# ...

# %%
b.fetch("census/demographic_profile/2018/acs_2018_ACS_2018_5YR_TRACT_tract.parquet", "./acs_2018_ACS_2018_5YR_TRACT_tract.parquet")
# Out:
# 100%|██████████| 578M/578M [00:09<00:00, 60.2MB/s]

# %%
tracts = pandas.read_parquet('./acs_2018_ACS_2018_5YR_TRACT_tract.parquet')

# %%
tracts.head()
# Out:
#             STATEFP COUNTYFP TRACTCE   NAME            NAMELSAD  MTFCC  \
# GEOID
# 01087232100      01      087  232100   2321   Census Tract 2321  G5020
# 01101002201      01      101  002201  22.01  Census Tract 22.01  G5020
# 01101002202      01      101  002202  22.02  Census Tract 22.02  G5020
# 01101002300      01      101  002300     23     Census Tract 23  G5020
# 01101002400      01      101  002400     24     Census Tract 24  G5020
#
#             FUNCSTAT      ALAND    AWATER     INTPTLAT      INTPTLON  \
# GEOID
# 01087232100        S  5357837.0   58722.0  +32.4037650  -085.7172586
# 01101002201        S  3121070.0       0.0  +32.3356125  -086.3078025
# 01101002202        S  2891661.0   81899.0  +32.3151157  -086.3030980
# 01101002300        S  3185680.0  100230.0  +32.3340804  -086.3219320
# 01101002400        S  3709019.0   57096.0  +32.3413010  -086.3351156
#
#              Shape_Length  Shape_Area          GEOID_Data  \
# GEOID
# ...

# %%
b.fetch("census/demographic_profile/2018/acs_2018_X02_RACE_tract.parquet", "./acs_2018_X02_RACE_tract.parquet")
# Out:
# 100%|██████████| 7.28M/7.28M [00:03<00:00, 2.34MB/s]

# %%
tracts = pandas.read_parquet('./acs_2018_X02_RACE_tract.parquet')

# %%
tracts.head()
# Out:
#                     B02001_001E  B02001_002E  B02001_003E  B02001_004E  \
# GEOID
# 14000US02090001700       1202.0       1115.0          0.0         39.0
# 14000US02090001800       3162.0       2576.0        166.0         43.0
# 14000US02090001900      10918.0       9580.0         22.0        323.0
# 14000US02100000100       2518.0       2040.0          1.0        217.0
# 14000US02105000200         47.0          6.0          0.0         35.0
#
#                     B02001_005E  B02001_006E  B02001_007E  B02001_008E  \
# GEOID
# 14000US02090001700          7.0         31.0          0.0         10.0
# 14000US02090001800        124.0          0.0         68.0        185.0
# 14000US02090001900        138.0          0.0        212.0        643.0
# 14000US02100000100         74.0          4.0         11.0        171.0
# 14000US02105000200          0.0          0.0          0.0          6.0
#
#                     B02001_009E  B02001_010E  ...  C02003_010E  C02003_011E  \
# ...
