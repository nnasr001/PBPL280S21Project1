# %%
import pandas
import pandas as pd
import geopandas as gpd
from tobler.area_weighted import area_interpolate
from tobler.dasymetric import masked_area_interpolate
import matplotlib.pyplot as plt
import seaborn as sns

# %%
income = gpd.read_parquet('./income/ca_tract_incomes.parquet')

# %%
income.head()
# Out:
#          GEOID  median_household_income  median_home_value  per_capita_income  \
# 0  06037554001                  55703.0           450200.0            23331.0
# 1  06037554002                  56452.0           461200.0            22520.0
# 2  06037554101                  42969.0           453200.0            19127.0
# 3  06037554103                  81480.0           460200.0            34880.0
# 4  06037554104                  63625.0           464800.0            20344.0
#
#                                             geometry
# 0  POLYGON ((5987925.784 2275112.258, 5988249.105...
# 1  POLYGON ((5987299.089 2275049.015, 5987348.882...
# 2  POLYGON ((5992628.264 2276367.468, 5992690.382...
# 3  POLYGON ((5992635.820 2276956.239, 5992710.707...
# 4  POLYGON ((5993599.563 2274986.574, 5993703.488...

# %%
income.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 8057 entries, 0 to 8056
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   GEOID                    8057 non-null   object
#  1   median_household_income  7965 non-null   float64
#  2   median_home_value        7831 non-null   float64
#  3   per_capita_income        8007 non-null   float64
#  4   geometry                 8057 non-null   geometry
# dtypes: float64(3), geometry(1), object(1)
# memory usage: 377.7+ KB

# %%
income['GEOID'] = income['GEOID'].astype(str).str[:5]

# %%
income.GEOID.astype('object')
# Out:
# 0       06037
# 1       06037
# 2       06037
# 3       06037
# 4       06037
#         ...
# 8052    06115
# 8053    06115
# 8054    06115
# 8055    06115
# 8056    06115
# Name: GEOID, Length: 8057, dtype: object

# %%
income.head()
# Out:
#    GEOID  median_household_income  median_home_value  per_capita_income  \
# 0  06037                  55703.0           450200.0            23331.0
# 1  06037                  56452.0           461200.0            22520.0
# 2  06037                  42969.0           453200.0            19127.0
# 3  06037                  81480.0           460200.0            34880.0
# 4  06037                  63625.0           464800.0            20344.0
#
#                                             geometry
# 0  POLYGON ((5987925.784 2275112.258, 5988249.105...
# 1  POLYGON ((5987299.089 2275049.015, 5987348.882...
# 2  POLYGON ((5992628.264 2276367.468, 5992690.382...
# 3  POLYGON ((5992635.820 2276956.239, 5992710.707...
# 4  POLYGON ((5993599.563 2274986.574, 5993703.488...

# %%
income.shape
# Out:
# (8057, 5)

# %%
county_income = income[['GEOID','geometry','median_household_income', 'median_home_value', 'per_capita_income']]

# %%
county_income.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 8057 entries, 0 to 8056
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   GEOID                    8057 non-null   object
#  1   geometry                 8057 non-null   geometry
#  2   median_household_income  7965 non-null   float64
#  3   median_home_value        7831 non-null   float64
#  4   per_capita_income        8007 non-null   float64
# dtypes: float64(3), geometry(1), object(1)
# memory usage: 377.7+ KB

# %%
county_income.to_csv('county-income.csv')

# %%
county_income.plot(column='median_household_income', scheme='FisherJenks', k=5, legend=True, figsize=(15,15))
# Out:
# <AxesSubplot:>

# %%
plt.savefig('county_income.png')

# %%
county_income.plot(column='median_home_value', scheme='FisherJenks', k=5, legend=True, figsize=(15,15))
# Out:
# <AxesSubplot:>

# %%
plt.savefig('median_home_value.png')

# %%
#crs

# %%
county_income.plot(column='per_capita_income', scheme='FisherJenks', k=5, legend=True, figsize=(15,15))
# Out:
# <AxesSubplot:>

# %%
plt.savefig('per_capita_income.png')

# %%
county_income.crs

# %%
#School County Data

# %%
sch = gpd.read_parquet('SchoolCounty_Data.parquet')

# %%
sch.head()
# Out:
#    geoid                                           geometry   fips       name  \
# 0  06001  POLYGON ((-122.28088 37.70723, -122.28178 37.7...  06001    Alameda
# 1  06005  POLYGON ((-121.02729 38.48136, -121.02729 38.4...  06005     Amador
# 3  06007  POLYGON ((-121.85650 39.53358, -121.85638 39.5...  06007      Butte
# 5  06009  POLYGON ((-120.63093 38.34110, -120.63057 38.3...  06009  Calaveras
# 6  06011  POLYGON ((-122.08018 39.41420, -122.07996 39.4...  06011     Colusa
#
#   state CountyName  ChronicAbsenteeismCount  CumulativeEnrollment  absentrate  \
# 0    CA    Alameda                 373198.0             2345464.0    0.159115
# 1    CA     Amador                   7356.0               48087.0    0.152973
# 3    CA      Butte                  58888.0              338729.0    0.173850
# 5    CA  Calaveras                   9848.0               58591.0    0.168080
# 6    CA     Colusa                   5371.0               60099.0    0.089369
#
#    Dropout (Rate)  Regular HS Diploma Graduates (Rate)
# 0         46304.3                             345454.1
# 1           863.6                              18292.4
# 3         17108.3                              88204.6
# 5          1854.2                              29262.6
# 6          2365.2                              29169.2

# %%
sch.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 57 entries, 0 to 84
# Data columns (total 11 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   geoid                                57 non-null     object
#  1   geometry                             57 non-null     geometry
#  2   fips                                 57 non-null     object
#  3   name                                 57 non-null     object
#  4   state                                57 non-null     object
#  5   CountyName                           57 non-null     object
#  6   ChronicAbsenteeismCount              57 non-null     float64
#  7   CumulativeEnrollment                 57 non-null     float64
#  8   absentrate                           57 non-null     float64
#  9   Dropout (Rate)                       57 non-null     float64
#  10  Regular HS Diploma Graduates (Rate)  57 non-null     float64
# dtypes: float64(5), geometry(1), object(5)
# memory usage: 5.3+ KB

# %%
sch.head()
# Out:
#    geoid                                           geometry   fips       name  \
# 0  06001  POLYGON ((-122.28088 37.70723, -122.28178 37.7...  06001    Alameda
# 1  06005  POLYGON ((-121.02729 38.48136, -121.02729 38.4...  06005     Amador
# 3  06007  POLYGON ((-121.85650 39.53358, -121.85638 39.5...  06007      Butte
# 5  06009  POLYGON ((-120.63093 38.34110, -120.63057 38.3...  06009  Calaveras
# 6  06011  POLYGON ((-122.08018 39.41420, -122.07996 39.4...  06011     Colusa
#
#   state CountyName  ChronicAbsenteeismCount  CumulativeEnrollment  absentrate  \
# 0    CA    Alameda                 373198.0             2345464.0    0.159115
# 1    CA     Amador                   7356.0               48087.0    0.152973
# 3    CA      Butte                  58888.0              338729.0    0.173850
# 5    CA  Calaveras                   9848.0               58591.0    0.168080
# 6    CA     Colusa                   5371.0               60099.0    0.089369
#
#    Dropout (Rate)  Regular HS Diploma Graduates (Rate)
# 0         46304.3                             345454.1
# 1           863.6                              18292.4
# 3         17108.3                              88204.6
# 5          1854.2                              29262.6
# 6          2365.2                              29169.2

# %%
sch.columns
# Out:
# Index(['geoid', 'geometry', 'fips', 'name', 'state', 'CountyName',
#        'ChronicAbsenteeismCount', 'CumulativeEnrollment', 'absentrate',
#        'Dropout (Rate)', 'Regular HS Diploma Graduates (Rate)'],
#       dtype='object')

# %%
sch.plot(column='absentrate', scheme='FisherJenks', k=5, legend=True, figsize=(15,15))
# Out:
# <AxesSubplot:>

# %%
plt.savefig('sch_absentrate.png')

# %%
sch.plot(column='Regular HS Diploma Graduates (Rate)', scheme='FisherJenks', k=5, legend=True, figsize=(15,15))
# Out:
# <AxesSubplot:>

# %%
plt.savefig('sch_hsgradrate.png')

# %%
#crs

# %%
sch.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
county_income.crs = "EPSG:4326"

# %%
county_income = county_income.to_crs(sch.crs)

# %%
county_income.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
county_income.head()
# Out:
#    GEOID                                           geometry  \
# 0  06037  POLYGON ((5987925.784 2275112.258, 5988249.105...
# 1  06037  POLYGON ((5987299.089 2275049.015, 5987348.882...
# 2  06037  POLYGON ((5992628.264 2276367.468, 5992690.382...
# 3  06037  POLYGON ((5992635.820 2276956.239, 5992710.707...
# 4  06037  POLYGON ((5993599.563 2274986.574, 5993703.488...
#
#    median_household_income  median_home_value  per_capita_income
# 0                  55703.0           450200.0            23331.0
# 1                  56452.0           461200.0            22520.0
# 2                  42969.0           453200.0            19127.0
# 3                  81480.0           460200.0            34880.0
# 4                  63625.0           464800.0            20344.0

# %%
county_income=county_income.reset_index()

# %%
county_income.head()
# Out:
#    index  GEOID                                           geometry  \
# 0      0  06037  POLYGON ((5987925.784 2275112.258, 5988249.105...
# 1      1  06037  POLYGON ((5987299.089 2275049.015, 5987348.882...
# 2      2  06037  POLYGON ((5992628.264 2276367.468, 5992690.382...
# 3      3  06037  POLYGON ((5992635.820 2276956.239, 5992710.707...
# 4      4  06037  POLYGON ((5993599.563 2274986.574, 5993703.488...
#
#    median_household_income  median_home_value  per_capita_income
# 0                  55703.0           450200.0            23331.0
# 1                  56452.0           461200.0            22520.0
# 2                  42969.0           453200.0            19127.0
# 3                  81480.0           460200.0            34880.0
# 4                  63625.0           464800.0            20344.0

# %%
county_income.rename(columns = {'GEOID':'geoid'}, inplace = True)

# %%
county_income.head()
# Out:
#    index  geoid                                           geometry  \
# 0      0  06037  POLYGON ((5987925.784 2275112.258, 5988249.105...
# 1      1  06037  POLYGON ((5987299.089 2275049.015, 5987348.882...
# 2      2  06037  POLYGON ((5992628.264 2276367.468, 5992690.382...
# 3      3  06037  POLYGON ((5992635.820 2276956.239, 5992710.707...
# 4      4  06037  POLYGON ((5993599.563 2274986.574, 5993703.488...
#
#    median_household_income  median_home_value  per_capita_income
# 0                  55703.0           450200.0            23331.0
# 1                  56452.0           461200.0            22520.0
# 2                  42969.0           453200.0            19127.0
# 3                  81480.0           460200.0            34880.0
# 4                  63625.0           464800.0            20344.0

# %%
socal_income = county_income[county_income.geoid == '60330,06059,06037,06073,06071,06083,06025,06111']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-07f915ad5e5b> in <module>
# ----> 1 socal_income = county_income[county_income.geoid == '60330,06059,06037,06073,06071,06083,06025,06111']
#
# NameError: name 'county_income' is not defined

# %%
socal_income.head()

# %%
sch_income.head()
# Out:
#    geoid                                         geometry_x   fips       name  \
# 0  06001  POLYGON ((-122.28088 37.70723, -122.28178 37.7...  06001    Alameda
# 1  06005  POLYGON ((-121.02729 38.48136, -121.02729 38.4...  06005     Amador
# 2  06007  POLYGON ((-121.85650 39.53358, -121.85638 39.5...  06007      Butte
# 3  06009  POLYGON ((-120.63093 38.34110, -120.63057 38.3...  06009  Calaveras
# 4  06011  POLYGON ((-122.08018 39.41420, -122.07996 39.4...  06011     Colusa
#
#   state CountyName  ChronicAbsenteeismCount  CumulativeEnrollment  absentrate  \
# 0    CA    Alameda                 373198.0             2345464.0    0.159115
# 1    CA     Amador                   7356.0               48087.0    0.152973
# 2    CA      Butte                  58888.0              338729.0    0.173850
# 3    CA  Calaveras                   9848.0               58591.0    0.168080
# 4    CA     Colusa                   5371.0               60099.0    0.089369
#
#    Dropout (Rate)  Regular HS Diploma Graduates (Rate)  \
# 0         46304.3                             345454.1
# 1           863.6                              18292.4
# 2         17108.3                              88204.6
# 3          1854.2                              29262.6
# 4          2365.2                              29169.2
#
#                                           geometry_y  median_household_income  \
# 0  POLYGON ((4917194.941 3614522.476, 4917150.603...               35617311.0
# 1  POLYGON ((5327665.355 3945457.409, 5327513.470...                 554908.0
# 2  POLYGON ((4952368.311 4287623.135, 4952479.510...                2584923.0
# 3  POLYGON ((5371063.042 3841172.558, 5371068.838...                 554899.0
# 4  POLYGON ((4940278.078 4225260.468, 4940281.870...                 276926.0
#
#    median_home_value  per_capita_income
# 0        249149602.0         16280835.0
# 1          2690900.0           272068.0
# 2         12915300.0          1373736.0
# 3          2975500.0           366966.0
# 4          1202700.0           138724.0

# %%
sch_income[['CountyName', 'geoid']].groupby
# Out:
# <bound method DataFrame.groupby of          CountyName  geoid
# 0           Alameda  06001
# 1            Amador  06005
# 2             Butte  06007
# 3         Calaveras  06009
# 4            Colusa  06011
# 5      Contra Costa  06013
# 6         Del Norte  06015
# 7         El Dorado  06017
# 8            Fresno  06019
# 9             Glenn  06021
# 10         Humboldt  06023
# 11         Imperial  06025
# 12             Inyo  06027
# 13             Kern  06029
# 14            Kings  06031
# 15             Lake  06033
# 16           Lassen  06035
# 17      Los Angeles  06037
# 18           Madera  06039
# 19            Marin  06041
# 20         Mariposa  06043
# 21        Mendocino  06045
# 22           Merced  06047
# 23            Modoc  06049
# 24             Mono  06051
# 25         Monterey  06053
# 26             Napa  06055
# 27           Nevada  06057
# 28           Orange  06059
# 29           Placer  06061
# 30           Plumas  06063
# 31        Riverside  06065
# 32       Sacramento  06067
# 33       San Benito  06069
# 34   San Bernardino  06071
# 35        San Diego  06073
# 36    San Francisco  06075
# 37      San Joaquin  06077
# 38  San Luis Obispo  06079
# 39        San Mateo  06081
# 40    Santa Barbara  06083
# 41      Santa Clara  06085
# 42       Santa Cruz  06087
# 43           Shasta  06089
# 44           Sierra  06091
# 45         Siskiyou  06093
# 46           Solano  06095
# 47           Sonoma  06097
# 48       Stanislaus  06099
# 49           Sutter  06101
# 50           Tehama  06103
# 51          Trinity  06105
# 52           Tulare  06107
# 53         Tuolumne  06109
# 54          Ventura  06111
# 55             Yolo  06113
# 56             Yuba  06115>

# %%
#sch_income .shape

# %%
#sch_income.plot()

# %%
demographic = gpd.read_parquet('demographics_tracts.parquet')

# %%
demographic.head()
# Out:
#         GEOID1  total_mf_10_19  \
# 0  06037137504           229.0
# 1  06037138000           404.0
# 2  06037139200           625.0
# 3  06067002300           259.0
# 4  06067002400           452.0
#
#                                             geometry
# 0  POLYGON ((-118.58119 34.14318, -118.58099 34.1...
# 1  POLYGON ((-118.60573 34.14585, -118.60561 34.1...
# 2  POLYGON ((-118.53082 34.18024, -118.52952 34.1...
# 3  POLYGON ((-121.50218 38.55643, -121.50184 38.5...
# 4  POLYGON ((-121.50970 38.54070, -121.50960 38.5...

# %%
demographic['GEOID1'] = demographic['GEOID1'].astype(str).str[:5]

# %%
income.GEOID.astype('object')
# Out:
# 0       06037
# 1       06037
# 2       06037
# 3       06037
# 4       06037
#         ...
# 8052    06115
# 8053    06115
# 8054    06115
# 8055    06115
# 8056    06115
# Name: GEOID, Length: 8057, dtype: object

# %%
dmg = demographic.dissolve(by='GEOID1', aggfunc='sum')

# %%
dmg.crs = "EPSG:4326"

# %%
dmg = dmg.to_crs(county_income.crs)

# %%
dmg.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
dmg.head()
# Out:
#                                                  geometry  total_mf_10_19
# GEOID1
# 06001   POLYGON ((-121.90392 37.46454, -121.90407 37.4...        189657.0
# 06003   POLYGON ((-120.07333 38.70109, -120.07324 38.7...           193.0
# 06005   POLYGON ((-120.54130 38.42291, -120.54181 38.4...          3705.0
# 06007   POLYGON ((-121.90870 39.30799, -121.90834 39.3...         27187.0
# 06009   POLYGON ((-120.37620 38.14265, -120.37616 38.1...          4245.0

# %%
dmg.head()
# Out:
#                                                  geometry  total_mf_10_19
# GEOID1
# 06001   POLYGON ((-121.90392 37.46454, -121.90407 37.4...        189657.0
# 06003   POLYGON ((-120.07333 38.70109, -120.07324 38.7...           193.0
# 06005   POLYGON ((-120.54130 38.42291, -120.54181 38.4...          3705.0
# 06007   POLYGON ((-121.90870 39.30799, -121.90834 39.3...         27187.0
# 06009   POLYGON ((-120.37620 38.14265, -120.37616 38.1...          4245.0

# %%
dmg.rename(columns = {'GEOID1':'geoid'}, inplace = True)

# %%
dmg.head()
# Out:
#                                                  geometry  total_mf_10_19
# GEOID1
# 06001   POLYGON ((-121.90392 37.46454, -121.90407 37.4...        189657.0
# 06003   POLYGON ((-120.07333 38.70109, -120.07324 38.7...           193.0
# 06005   POLYGON ((-120.54130 38.42291, -120.54181 38.4...          3705.0
# 06007   POLYGON ((-121.90870 39.30799, -121.90834 39.3...         27187.0
# 06009   POLYGON ((-120.37620 38.14265, -120.37616 38.1...          4245.0

# %%
dmg=dmg.reset_index()

# %%
dmg.head()
# Out:
#   GEOID1                                           geometry  total_mf_10_19
# 0  06001  POLYGON ((-121.90392 37.46454, -121.90407 37.4...        189657.0
# 1  06003  POLYGON ((-120.07333 38.70109, -120.07324 38.7...           193.0
# 2  06005  POLYGON ((-120.54130 38.42291, -120.54181 38.4...          3705.0
# 3  06007  POLYGON ((-121.90870 39.30799, -121.90834 39.3...         27187.0
# 4  06009  POLYGON ((-120.37620 38.14265, -120.37616 38.1...          4245.0

# %%
dmg_sch.head()
# Out:
#    geoid                                  geometry_county_x   fips       name  \
# 0  06001  POLYGON ((-122.28088 37.70723, -122.28178 37.7...  06001    Alameda
# 1  06005  POLYGON ((-121.02729 38.48136, -121.02729 38.4...  06005     Amador
# 2  06007  POLYGON ((-121.85650 39.53358, -121.85638 39.5...  06007      Butte
# 3  06009  POLYGON ((-120.63093 38.34110, -120.63057 38.3...  06009  Calaveras
# 4  06011  POLYGON ((-122.08018 39.41420, -122.07996 39.4...  06011     Colusa
#
#   state CountyName  ChronicAbsenteeismCount  CumulativeEnrollment  absentrate  \
# 0    CA    Alameda                 373198.0             2345464.0    0.159115
# 1    CA     Amador                   7356.0               48087.0    0.152973
# 2    CA      Butte                  58888.0              338729.0    0.173850
# 3    CA  Calaveras                   9848.0               58591.0    0.168080
# 4    CA     Colusa                   5371.0               60099.0    0.089369
#
#    Dropout (Rate)  Regular HS Diploma Graduates (Rate)  \
# 0         46304.3                             345454.1
# 1           863.6                              18292.4
# 2         17108.3                              88204.6
# 3          1854.2                              29262.6
# 4          2365.2                              29169.2
#
#                                           geometry_y  median_household_income  \
# 0  POLYGON ((4917194.941 3614522.476, 4917150.603...               35617311.0
# 1  POLYGON ((5327665.355 3945457.409, 5327513.470...                 554908.0
# 2  POLYGON ((4952368.311 4287623.135, 4952479.510...                2584923.0
# 3  POLYGON ((5371063.042 3841172.558, 5371068.838...                 554899.0
# 4  POLYGON ((4940278.078 4225260.468, 4940281.870...                 276926.0
#
#    median_home_value  per_capita_income  index  \
# 0        249149602.0         16280835.0      0
# 1          2690900.0           272068.0      2
# 2         12915300.0          1373736.0      3
# 3          2975500.0           366966.0      4
# 4          1202700.0           138724.0      5
#
#                                    geometry_county_y  total_mf_10_19
# 0  POLYGON ((-121.90392 37.46454, -121.90407 37.4...        189657.0
# 1  POLYGON ((-120.54130 38.42291, -120.54181 38.4...          3705.0
# 2  POLYGON ((-121.90870 39.30799, -121.90834 39.3...         27187.0
# 3  POLYGON ((-120.37620 38.14265, -120.37616 38.1...          4245.0
# 4  POLYGON ((-121.93917 39.13614, -121.93915 39.1...          3177.0

# %%
dmg_sch.to_csv('school-demographic.csv')

# %%
sns.scatterplot(data=dmg_sch, y="absentrate", x="total_mf_10_19")
# Out:
# <AxesSubplot:xlabel='total_mf_10_19', ylabel='absentrate'>

# %%
base = sch.plot(column='absentrate', scheme='Quantiles', k=5, legend=True)
county_income.plot(ax=base, color='blue')
# Out:
# <AxesSubplot:>

# %%
base = sch.geometry.boundary.plot(edgecolor='blue')
county_income.geometry.boundary.plot(ax=base, edgecolor='green')
dmg.plot(color='red', ax=base)
# Out:
# <AxesSubplot:>

# %%
county_income.plot(column='median_household_income', scheme='Quantiles', k=5, legend=True)
# Out:
# <AxesSubplot:>

# %%
sch.plot(column='absentrate', scheme='Quantiles', k=5, legend=True)
# Out:
# <AxesSubplot:>

# %%
county_income.plot(column='', scheme='Quantiles', k=5, legend=True)

# %%
base  = sch.plot(column='absentrate', legend=True)
county_income.plot(color='red', ax=base)
# Out:
# <AxesSubplot:>

# %%
schools_income = gpd.sjoin(sch, county_income, how='left', op='within')

# %%
schools_income
# Out:
#    geoid_left                                           geometry   fips  \
# 0       06001  POLYGON ((-122.28088 37.70723, -122.28178 37.7...  06001
# 1       06005  POLYGON ((-121.02729 38.48136, -121.02729 38.4...  06005
# 3       06007  POLYGON ((-121.85650 39.53358, -121.85638 39.5...  06007
# 5       06009  POLYGON ((-120.63093 38.34110, -120.63057 38.3...  06009
# 6       06011  POLYGON ((-122.08018 39.41420, -122.07996 39.4...  06011
# 7       06013  POLYGON ((-122.26764 37.90425, -122.26781 37.9...  06013
# 8       06015  POLYGON ((-124.31611 41.72839, -124.33061 41.7...  06015
# 9       06017  POLYGON ((-121.11862 38.71712, -121.11876 38.7...  06017
# 10      06019  POLYGON ((-119.70536 36.99979, -119.70502 37.0...  06019
# 11      06021  POLYGON ((-122.89094 39.64487, -122.89134 39.6...  06021
# 13      06023  POLYGON ((-124.28140 40.79915, -124.28018 40.7...  06023
# 15      06025  POLYGON ((-115.33554 32.67611, -115.33576 32.6...  06025
# 16      06027  POLYGON ((-118.33758 36.65480, -118.33773 36.6...  06027
# 17      06029  POLYGON ((-119.91366 35.43926, -119.92327 35.4...  06029
# 18      06031  POLYGON ((-119.95892 36.25547, -119.95893 36.2...  06031
# 31      06033  POLYGON ((-123.06515 39.05918, -123.06515 39.0...  06033
# 32      06035  POLYGON ((-121.32191 40.65496, -121.32181 40.6...  06035
# 33      06037  MULTIPOLYGON (((-118.66760 33.47749, -118.6682...  06037
# 34      06039  POLYGON ((-120.10639 37.16715, -120.10577 37.1...  06039
# 35      06041  POLYGON ((-122.78639 37.88695, -122.78704 37.8...  06041
# 36      06043  POLYGON ((-120.32153 37.52440, -120.32156 37.5...  06043
# 37      06045  POLYGON ((-123.83841 39.55492, -123.83965 39.5...  06045
# 38      06047  POLYGON ((-120.68159 37.51863, -120.67691 37.5...  06047
# 39      06049  POLYGON ((-120.15941 41.99460, -120.15923 41.9...  06049
# 40      06051  POLYGON ((-119.30890 38.00715, -119.30886 38.0...  06051
# 41      06053  POLYGON ((-122.02681 36.54641, -122.02702 36.5...  06053
# 42      06055  POLYGON ((-122.46389 38.70520, -122.46388 38.7...  06055
# 43      06057  POLYGON ((-120.71374 39.48279, -120.71370 39.4...  06057
# 51      06059  POLYGON ((-117.98910 33.58579, -117.99067 33.5...  06059
# 53      06061  POLYGON ((-121.06544 39.00653, -121.06537 39.0...  06061
# 54      06063  POLYGON ((-121.36701 40.07767, -121.36688 40.0...  06063
# 55      06065  POLYGON ((-117.67284 33.86991, -117.67287 33.8...  06065
# 56      06067  POLYGON ((-121.18857 38.71431, -121.18731 38.7...  06067
# 57      06069  POLYGON ((-121.48300 36.76505, -121.48351 36.7...  06069
# 58      06071  POLYGON ((-117.66724 34.73433, -117.66724 34.7...  06071
# 59      06073  POLYGON ((-117.43743 33.17953, -117.44954 33.1...  06073
# 60      06075  MULTIPOLYGON (((-122.60024 37.80248, -122.6122...  06075
# 61      06077  POLYGON ((-121.20789 38.24882, -121.20703 38.2...  06077
# 62      06079  POLYGON ((-121.18506 35.79416, -121.18463 35.7...  06079
# 63      06081  POLYGON ((-122.58711 37.58755, -122.58679 37.5...  06081
# 64      06083  MULTIPOLYGON (((-120.58190 34.09856, -120.5822...  06083
# 65      06085  POLYGON ((-122.04412 37.20049, -122.04409 37.2...  06085
# 67      06087  POLYGON ((-122.21668 37.21521, -122.21651 37.2...  06087
# 68      06089  POLYGON ((-122.61527 40.88107, -122.61473 40.8...  06089
# 69      06091  POLYGON ((-120.65559 39.69356, -120.65552 39.6...  06091
# 71      06093  POLYGON ((-122.87087 42.00396, -122.86813 42.0...  06093
# 72      06095  POLYGON ((-122.06478 38.31591, -122.06508 38.3...  06095
# 73      06097  POLYGON ((-122.93506 38.31395, -122.93509 38.3...  06097
# 74      06099  POLYGON ((-120.92225 37.73748, -120.92159 37.7...  06099
# 76      06101  POLYGON ((-121.92833 39.19873, -121.92872 39.1...  06101
# 77      06103  POLYGON ((-122.37148 40.37261, -122.37046 40.3...  06103
# 78      06105  POLYGON ((-123.54396 40.73294, -123.54386 40.7...  06105
# 80      06107  POLYGON ((-118.80373 35.79035, -118.80496 35.7...  06107
# 81      06109  POLYGON ((-120.50016 38.00412, -120.50025 38.0...  06109
# 82      06111  MULTIPOLYGON (((-119.63630 33.27304, -119.6360...  06111
# 83      06113  POLYGON ((-122.16494 38.64246, -122.16398 38.6...  06113
# 84      06115  POLYGON ((-121.59768 39.12779, -121.59781 39.1...  06115
#
#                name state       CountyName  ChronicAbsenteeismCount  \
# 0           Alameda    CA          Alameda                 373198.0
# 1            Amador    CA           Amador                   7356.0
# 3             Butte    CA            Butte                  58888.0
# 5         Calaveras    CA        Calaveras                   9848.0
# 6            Colusa    CA           Colusa                   5371.0
# 7      Contra Costa    CA     Contra Costa                 226112.0
# 8         Del Norte    CA        Del Norte                   9230.0
# 9         El Dorado    CA        El Dorado                  30818.0
# 10           Fresno    CA           Fresno                 296474.0
# 11            Glenn    CA            Glenn                   7221.0
# 13         Humboldt    CA         Humboldt                  32797.0
# 15         Imperial    CA         Imperial                  55630.0
# 16             Inyo    CA             Inyo                   4622.0
# 17             Kern    CA             Kern                 254056.0
# 18            Kings    CA            Kings                  29564.0
# 31             Lake    CA             Lake                  25657.0
# 32           Lassen    CA           Lassen                   6864.0
# 33      Los Angeles    CA      Los Angeles                2137114.0
# 34           Madera    CA           Madera                  47322.0
# 35            Marin    CA            Marin                  32465.0
# 36         Mariposa    CA         Mariposa                   4105.0
# 37        Mendocino    CA        Mendocino                  29340.0
# 38           Merced    CA           Merced                  90080.0
# 39            Modoc    CA            Modoc                   3711.0
# 40             Mono    CA             Mono                   2062.0
# 41         Monterey    CA         Monterey                 107865.0
# 42             Napa    CA             Napa                  26548.0
# 43           Nevada    CA           Nevada                  13122.0
# 51           Orange    CA           Orange                 470658.0
# 53           Placer    CA           Placer                  51659.0
# 54           Plumas    CA           Plumas                   5577.0
# 55        Riverside    CA        Riverside                 642050.0
# 56       Sacramento    CA       Sacramento                 359729.0
# 57       San Benito    CA       San Benito                  15115.0
# 58   San Bernardino    CA   San Bernardino                 633064.0
# 59        San Diego    CA        San Diego                 579235.0
# 60    San Francisco    CA    San Francisco                  93488.0
# 61      San Joaquin    CA      San Joaquin                 230791.0
# 62  San Luis Obispo    CA  San Luis Obispo                  45201.0
# 63        San Mateo    CA        San Mateo                  98969.0
# 64    Santa Barbara    CA    Santa Barbara                  81171.0
# 65      Santa Clara    CA      Santa Clara                 246931.0
# 67       Santa Cruz    CA       Santa Cruz                  48412.0
# 68           Shasta    CA           Shasta                  37866.0
# 69           Sierra    CA           Sierra                    168.0
# 71         Siskiyou    CA         Siskiyou                  11015.0
# 72           Solano    CA           Solano                 101862.0
# 73           Sonoma    CA           Sonoma                  77385.0
# 74       Stanislaus    CA       Stanislaus                 143705.0
# 76           Sutter    CA           Sutter                  27488.0
# 77           Tehama    CA           Tehama                  15906.0
# 78          Trinity    CA          Trinity                   3099.0
# 80           Tulare    CA           Tulare                 106752.0
# 81         Tuolumne    CA         Tuolumne                   9466.0
# 82          Ventura    CA          Ventura                 141006.0
# 83             Yolo    CA             Yolo                  41341.0
# 84             Yuba    CA             Yuba                  17805.0
#
#     CumulativeEnrollment  absentrate  Dropout (Rate)  \
# 0              2345464.0    0.159115         46304.3
# 1                48087.0    0.152973           863.6
# 3               338729.0    0.173850         17108.3
# 5                58591.0    0.168080          1854.2
# 6                60099.0    0.089369          2365.2
# 7              1792240.0    0.126162         29711.4
# 8                45492.0    0.202893          2919.3
# 9               269761.0    0.114242          7349.0
# 10             2352385.0    0.126031         53242.8
# 11               66047.0    0.109331          6634.6
# 13              189546.0    0.173029          7106.1
# 15              479905.0    0.115919         15674.6
# 16               30952.0    0.149328          8287.3
# 17             2187421.0    0.116144         37669.2
# 18              305214.0    0.096863         11082.8
# 31              118476.0    0.216559          9099.6
# 32               40399.0    0.169905          2064.0
# 33            15179823.0    0.140786        237715.4
# 34              371841.0    0.127264         11373.4
# 35              356818.0    0.090985          8800.0
# 36               21562.0    0.190381           608.0
# 37              151654.0    0.193467         13276.0
# 38              739236.0    0.121856         15121.1
# 39               17162.0    0.216234          1139.0
# 40               19371.0    0.106448         11355.2
# 41              958313.0    0.112557         17993.5
# 42              219482.0    0.120958          8488.8
# 43               79322.0    0.165427          9465.0
# 51             5351478.0    0.087949         47177.4
# 53              706035.0    0.073168         16621.6
# 54               22763.0    0.245003          2318.1
# 55             4947331.0    0.129777         58011.9
# 56             2585435.0    0.139137         51500.3
# 57              133872.0    0.112906          6155.2
# 58             4707147.0    0.134490        104093.6
# 59             5064892.0    0.114363         88182.0
# 60              635433.0    0.147125         23652.2
# 61             1605705.0    0.143732         46424.5
# 62              389137.0    0.116157          7997.6
# 63              972014.0    0.101818         18999.9
# 64              799368.0    0.101544         20185.1
# 65             2651967.0    0.093112         58946.3
# 67              414245.0    0.116868         17366.6
# 68              270100.0    0.140193         12492.9
# 69                4668.0    0.035990           222.0
# 71               65886.0    0.167183          3751.7
# 72              688186.0    0.148015         21272.3
# 73              583992.0    0.132510         33139.7
# 74             1243759.0    0.115541         39698.2
# 76              217906.0    0.126146          9952.2
# 77              136671.0    0.116382          5122.9
# 78               18030.0    0.171880          2541.6
# 80             1198005.0    0.089108         30004.9
# 81               62457.0    0.151560          3227.5
# 82             1530715.0    0.092118         26598.9
# 83              333665.0    0.123900         13637.0
# 84              169580.0    0.104995          8144.6
#
#     Regular HS Diploma Graduates (Rate)  index_right geoid_right  \
# 0                              345454.1          NaN         NaN
# 1                               18292.4          NaN         NaN
# 3                               88204.6          NaN         NaN
# 5                               29262.6          NaN         NaN
# 6                               29169.2          NaN         NaN
# 7                              235645.6          NaN         NaN
# 8                               20509.9          NaN         NaN
# 9                               58730.7          NaN         NaN
# 10                             269718.1          NaN         NaN
# 11                              28513.2          NaN         NaN
# 13                              74064.9          NaN         NaN
# 15                              68392.9          NaN         NaN
# 16                              19683.5          NaN         NaN
# 17                             206600.2          NaN         NaN
# 18                              65404.4          NaN         NaN
# 31                              40643.4          NaN         NaN
# 32                              20779.3          NaN         NaN
# 33                            1573140.9          NaN         NaN
# 34                              61728.5          NaN         NaN
# 35                              56958.2          NaN         NaN
# 36                              11886.8          NaN         NaN
# 37                              56777.4          NaN         NaN
# 38                             109191.1          NaN         NaN
# 39                               9962.2          NaN         NaN
# 40                               6851.8          NaN         NaN
# 41                             111231.3          NaN         NaN
# 42                              41941.6          NaN         NaN
# 43                              32119.2          NaN         NaN
# 51                             455837.9          NaN         NaN
# 53                             119989.1          NaN         NaN
# 54                              14866.4          NaN         NaN
# 55                             483009.5          NaN         NaN
# 56                             318983.6          NaN         NaN
# 57                              16602.4          NaN         NaN
# 58                             436512.6          NaN         NaN
# 59                             570681.3          NaN         NaN
# 60                              92315.2          NaN         NaN
# 61                             225581.7          NaN         NaN
# 62                              89496.5          NaN         NaN
# 63                             139110.7          NaN         NaN
# 64                             100062.6          NaN         NaN
# 65                             272796.9          NaN         NaN
# 67                              84375.1          NaN         NaN
# 68                              84289.0          NaN         NaN
# 69                               5778.4          NaN         NaN
# 71                              32813.0          NaN         NaN
# 72                             112303.9          NaN         NaN
# 73                             129642.3          NaN         NaN
# 74                             164562.4          NaN         NaN
# 76                              64299.8          NaN         NaN
# 77                              34648.6          NaN         NaN
# 78                              11066.3          NaN         NaN
# 80                             167143.9          NaN         NaN
# 81                              26419.1          NaN         NaN
# 82                             161166.2          NaN         NaN
# 83                              64771.0          NaN         NaN
# 84                              41589.0          NaN         NaN
#
#     median_household_income  median_home_value  per_capita_income
# 0                       NaN                NaN                NaN
# 1                       NaN                NaN                NaN
# 3                       NaN                NaN                NaN
# 5                       NaN                NaN                NaN
# 6                       NaN                NaN                NaN
# 7                       NaN                NaN                NaN
# 8                       NaN                NaN                NaN
# 9                       NaN                NaN                NaN
# 10                      NaN                NaN                NaN
# 11                      NaN                NaN                NaN
# 13                      NaN                NaN                NaN
# 15                      NaN                NaN                NaN
# 16                      NaN                NaN                NaN
# 17                      NaN                NaN                NaN
# 18                      NaN                NaN                NaN
# 31                      NaN                NaN                NaN
# 32                      NaN                NaN                NaN
# 33                      NaN                NaN                NaN
# 34                      NaN                NaN                NaN
# 35                      NaN                NaN                NaN
# 36                      NaN                NaN                NaN
# 37                      NaN                NaN                NaN
# 38                      NaN                NaN                NaN
# 39                      NaN                NaN                NaN
# 40                      NaN                NaN                NaN
# 41                      NaN                NaN                NaN
# 42                      NaN                NaN                NaN
# 43                      NaN                NaN                NaN
# 51                      NaN                NaN                NaN
# 53                      NaN                NaN                NaN
# 54                      NaN                NaN                NaN
# 55                      NaN                NaN                NaN
# 56                      NaN                NaN                NaN
# 57                      NaN                NaN                NaN
# 58                      NaN                NaN                NaN
# 59                      NaN                NaN                NaN
# 60                      NaN                NaN                NaN
# 61                      NaN                NaN                NaN
# 62                      NaN                NaN                NaN
# 63                      NaN                NaN                NaN
# 64                      NaN                NaN                NaN
# 65                      NaN                NaN                NaN
# 67                      NaN                NaN                NaN
# 68                      NaN                NaN                NaN
# 69                      NaN                NaN                NaN
# 71                      NaN                NaN                NaN
# 72                      NaN                NaN                NaN
# 73                      NaN                NaN                NaN
# 74                      NaN                NaN                NaN
# 76                      NaN                NaN                NaN
# 77                      NaN                NaN                NaN
# 78                      NaN                NaN                NaN
# 80                      NaN                NaN                NaN
# 81                      NaN                NaN                NaN
# 82                      NaN                NaN                NaN
# 83                      NaN                NaN                NaN
# 84                      NaN                NaN                NaN
